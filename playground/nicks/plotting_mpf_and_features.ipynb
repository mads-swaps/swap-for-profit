# %%
import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpf
import numpy as np

pd.set_option('display.max_columns', 500)

df = pd.read_pickle('data/candlestick_15m_ETHBTC_2107291134.pkl')
df.set_index('open_time', inplace=True)
df.sort_index(inplace=True)
df.tail()
# Out:
#                      pair_id          close_time  dow       tod      open  \
# open_time
# 2021-07-29 01:00:00        0 2021-07-29 01:14:59    4  0.041667  0.057756
# 2021-07-29 01:15:00        0 2021-07-29 01:29:59    4  0.052083  0.057657
# 2021-07-29 01:30:00        0 2021-07-29 01:44:59    4  0.062500  0.057696
# 2021-07-29 01:45:00        0 2021-07-29 01:59:59    4  0.072917  0.057629
# 2021-07-29 02:00:00        0 2021-07-29 02:14:59    4  0.083333  0.057599
#
#                          high       low     close  number_of_trades    volume  \
# open_time
# 2021-07-29 01:00:00  0.057776  0.057576  0.057657              1822  1126.414
# 2021-07-29 01:15:00  0.057788  0.057612  0.057697              1555  1039.405
# 2021-07-29 01:30:00  0.057734  0.057597  0.057639              1005   561.893
# 2021-07-29 01:45:00  0.057647  0.057540  0.057600              1462   937.077
# 2021-07-29 02:00:00  0.057664  0.057531  0.057588              1487   905.711
#
#                      quote_asset_volume  taker_buy_base_asset_volume  \
# open_time
# 2021-07-29 01:00:00           64.976710                      523.396
# 2021-07-29 01:15:00           59.982518                      595.068
# 2021-07-29 01:30:00           32.396800                      242.236
# 2021-07-29 01:45:00           53.973107                      478.205
# 2021-07-29 02:00:00           52.167408                      487.870
#
#                      taker_buy_quote_asset_volume      ma14      ma30  \
# open_time
# 2021-07-29 01:00:00                     30.191289  0.057749  0.057651
# 2021-07-29 01:15:00                     34.339625  0.057660  0.057701
# 2021-07-29 01:30:00                     13.966915  0.057693  0.057678
# 2021-07-29 01:45:00                     27.544769  0.057636  0.057665
# 2021-07-29 02:00:00                     28.099997  0.057599  0.057621
#
#                          ma90     sup14     sup30     sup90     res14  \
# open_time
# 2021-07-29 01:00:00  0.057531  0.057503  0.057300  0.057297  0.057776
# 2021-07-29 01:15:00  0.057544  0.057576  0.057365  0.057297  0.057788
# 2021-07-29 01:30:00  0.057574  0.057597  0.057503  0.057297  0.057788
# 2021-07-29 01:45:00  0.057607  0.057540  0.057540  0.057297  0.057734
# 2021-07-29 02:00:00  0.057638  0.057531  0.057531  0.057300  0.057664
#
#                         res30     res90       atr  atr_diff  atr_ma14  \
# open_time
# 2021-07-29 01:00:00  0.057776  0.057776  0.000166 -0.000002  0.000205
# 2021-07-29 01:15:00  0.057788  0.057788  0.000164 -0.000001  0.000198
# 2021-07-29 01:30:00  0.057788  0.057788  0.000176  0.000012  0.000192
# 2021-07-29 01:45:00  0.057788  0.057788  0.000183  0.000006  0.000186
# 2021-07-29 02:00:00  0.057788  0.057788  0.000190  0.000007  0.000184
#
#                            rsi   rsi_diff   rsi_ma14 trend_up trend_up3  \
# open_time
# 2021-07-29 01:00:00  65.783100  25.287404  49.758651    False     False
# 2021-07-29 01:15:00  37.933106 -27.849994  49.423081     True      True
# 2021-07-29 01:30:00  66.825027  28.891921  50.482451    False     False
# 2021-07-29 01:45:00  36.476762 -30.348264  49.994470    False     False
# 2021-07-29 02:00:00  64.754615  28.277853  50.327219    False     False
#
#                     trend_up14 trend_up30  cs_ss  cs_ssr  cs_hm  cs_hmr  \
# open_time
# 2021-07-29 01:00:00      False       True  False   False  False   False
# 2021-07-29 01:15:00       True       True  False   False  False   False
# 2021-07-29 01:30:00      False      False  False   False  False   False
# 2021-07-29 01:45:00      False      False  False   False  False   False
# 2021-07-29 02:00:00      False      False  False   False  False   False
#
#                      cs_brh cs_buh cs_ebu  cs_ebr    open_1    open_2  \
# open_time
# 2021-07-29 01:00:00   False  False  False   False  0.057564  0.057404
# 2021-07-29 01:15:00   False  False  False   False  0.057756  0.057564
# 2021-07-29 01:30:00   False  False  False   False  0.057657  0.057756
# 2021-07-29 01:45:00   False  False  False   False  0.057696  0.057657
# 2021-07-29 02:00:00   False  False  False   False  0.057629  0.057696
#
#                        open_3    open_4    open_5    open_6    open_7  \
# open_time
# 2021-07-29 01:00:00  0.057396  0.057493  0.057530  0.057650  0.057603
# 2021-07-29 01:15:00  0.057404  0.057396  0.057493  0.057530  0.057650
# 2021-07-29 01:30:00  0.057564  0.057404  0.057396  0.057493  0.057530
# 2021-07-29 01:45:00  0.057756  0.057564  0.057404  0.057396  0.057493
# 2021-07-29 02:00:00  0.057657  0.057756  0.057564  0.057404  0.057396
#
#                        open_8    open_9   open_10   open_11   open_12  \
# open_time
# 2021-07-29 01:00:00  0.057650  0.057633  0.057730  0.057488  0.057461
# 2021-07-29 01:15:00  0.057603  0.057650  0.057633  0.057730  0.057488
# 2021-07-29 01:30:00  0.057650  0.057603  0.057650  0.057633  0.057730
# 2021-07-29 01:45:00  0.057530  0.057650  0.057603  0.057650  0.057633
# 2021-07-29 02:00:00  0.057493  0.057530  0.057650  0.057603  0.057650
#
#                       open_13   open_14    high_1    high_2    high_3  \
# open_time
# 2021-07-29 01:00:00  0.057430  0.057430  0.057767  0.057570  0.057476
# 2021-07-29 01:15:00  0.057461  0.057430  0.057776  0.057767  0.057570
# 2021-07-29 01:30:00  0.057488  0.057461  0.057788  0.057776  0.057767
# 2021-07-29 01:45:00  0.057730  0.057488  0.057734  0.057788  0.057776
# 2021-07-29 02:00:00  0.057633  0.057730  0.057647  0.057734  0.057788
#
#                        high_4    high_5    high_6    high_7    high_8  \
# open_time
# 2021-07-29 01:00:00  0.057516  0.057592  0.057661  0.057669  0.057678
# 2021-07-29 01:15:00  0.057476  0.057516  0.057592  0.057661  0.057669
# 2021-07-29 01:30:00  0.057570  0.057476  0.057516  0.057592  0.057661
# 2021-07-29 01:45:00  0.057767  0.057570  0.057476  0.057516  0.057592
# 2021-07-29 02:00:00  0.057776  0.057767  0.057570  0.057476  0.057516
#
#                        high_9   high_10   high_11   high_12   high_13  \
# open_time
# 2021-07-29 01:00:00  0.057730  0.057782  0.057739  0.057572  0.057479
# 2021-07-29 01:15:00  0.057678  0.057730  0.057782  0.057739  0.057572
# 2021-07-29 01:30:00  0.057669  0.057678  0.057730  0.057782  0.057739
# 2021-07-29 01:45:00  0.057661  0.057669  0.057678  0.057730  0.057782
# 2021-07-29 02:00:00  0.057592  0.057661  0.057669  0.057678  0.057730
#
#                       high_14     low_1     low_2     low_3     low_4  \
# open_time
# 2021-07-29 01:00:00  0.057500  0.057503  0.057365  0.057300  0.057297
# 2021-07-29 01:15:00  0.057479  0.057576  0.057503  0.057365  0.057300
# 2021-07-29 01:30:00  0.057572  0.057612  0.057576  0.057503  0.057365
# 2021-07-29 01:45:00  0.057739  0.057597  0.057612  0.057576  0.057503
# 2021-07-29 02:00:00  0.057782  0.057540  0.057597  0.057612  0.057576
#
#                         low_5     low_6     low_7     low_8     low_9  \
# open_time
# 2021-07-29 01:00:00  0.057410  0.057470  0.057423  0.057569  0.057591
# 2021-07-29 01:15:00  0.057297  0.057410  0.057470  0.057423  0.057569
# 2021-07-29 01:30:00  0.057300  0.057297  0.057410  0.057470  0.057423
# 2021-07-29 01:45:00  0.057365  0.057300  0.057297  0.057410  0.057470
# 2021-07-29 02:00:00  0.057503  0.057365  0.057300  0.057297  0.057410
#
#                        low_10    low_11    low_12    low_13    low_14  \
# open_time
# 2021-07-29 01:00:00  0.057631  0.057483  0.057434  0.057400  0.057390
# 2021-07-29 01:15:00  0.057591  0.057631  0.057483  0.057434  0.057400
# 2021-07-29 01:30:00  0.057569  0.057591  0.057631  0.057483  0.057434
# 2021-07-29 01:45:00  0.057423  0.057569  0.057591  0.057631  0.057483
# 2021-07-29 02:00:00  0.057470  0.057423  0.057569  0.057591  0.057631
#
#                       close_1   close_2   close_3   close_4   close_5  \
# open_time
# 2021-07-29 01:00:00  0.057756  0.057564  0.057406  0.057394  0.057481
# 2021-07-29 01:15:00  0.057657  0.057756  0.057564  0.057406  0.057394
# 2021-07-29 01:30:00  0.057697  0.057657  0.057756  0.057564  0.057406
# 2021-07-29 01:45:00  0.057639  0.057697  0.057657  0.057756  0.057564
# 2021-07-29 02:00:00  0.057600  0.057639  0.057697  0.057657  0.057756
#
#                       close_6   close_7   close_8   close_9  close_10  \
# open_time
# 2021-07-29 01:00:00  0.057535  0.057654  0.057602  0.057659  0.057631
# 2021-07-29 01:15:00  0.057481  0.057535  0.057654  0.057602  0.057659
# 2021-07-29 01:30:00  0.057394  0.057481  0.057535  0.057654  0.057602
# 2021-07-29 01:45:00  0.057406  0.057394  0.057481  0.057535  0.057654
# 2021-07-29 02:00:00  0.057564  0.057406  0.057394  0.057481  0.057535
#
#                      close_11  close_12  close_13  close_14  \
# open_time
# 2021-07-29 01:00:00  0.057739  0.057480  0.057461  0.057430
# 2021-07-29 01:15:00  0.057631  0.057739  0.057480  0.057461
# 2021-07-29 01:30:00  0.057659  0.057631  0.057739  0.057480
# 2021-07-29 01:45:00  0.057602  0.057659  0.057631  0.057739
# 2021-07-29 02:00:00  0.057654  0.057602  0.057659  0.057631
#
#                      number_of_trades_1  number_of_trades_2  \
# open_time
# 2021-07-29 01:00:00              1704.0              1648.0
# 2021-07-29 01:15:00              1822.0              1704.0
# 2021-07-29 01:30:00              1555.0              1822.0
# 2021-07-29 01:45:00              1005.0              1555.0
# 2021-07-29 02:00:00              1462.0              1005.0
#
#                      number_of_trades_3  number_of_trades_4  \
# open_time
# 2021-07-29 01:00:00              1394.0              2261.0
# 2021-07-29 01:15:00              1648.0              1394.0
# 2021-07-29 01:30:00              1704.0              1648.0
# 2021-07-29 01:45:00              1822.0              1704.0
# 2021-07-29 02:00:00              1555.0              1822.0
#
#                      number_of_trades_5  number_of_trades_6  \
# open_time
# 2021-07-29 01:00:00              1386.0              1448.0
# 2021-07-29 01:15:00              2261.0              1386.0
# 2021-07-29 01:30:00              1394.0              2261.0
# 2021-07-29 01:45:00              1648.0              1394.0
# 2021-07-29 02:00:00              1704.0              1648.0
#
#                      number_of_trades_7  number_of_trades_8  \
# open_time
# 2021-07-29 01:00:00              2431.0              1296.0
# 2021-07-29 01:15:00              1448.0              2431.0
# 2021-07-29 01:30:00              1386.0              1448.0
# 2021-07-29 01:45:00              2261.0              1386.0
# 2021-07-29 02:00:00              1394.0              2261.0
#
#                      number_of_trades_9  number_of_trades_10  \
# open_time
# 2021-07-29 01:00:00              1066.0               1296.0
# 2021-07-29 01:15:00              1296.0               1066.0
# 2021-07-29 01:30:00              2431.0               1296.0
# 2021-07-29 01:45:00              1448.0               2431.0
# 2021-07-29 02:00:00              1386.0               1448.0
#
#                      number_of_trades_11  number_of_trades_12  \
# open_time
# 2021-07-29 01:00:00               1521.0               1295.0
# 2021-07-29 01:15:00               1296.0               1521.0
# 2021-07-29 01:30:00               1066.0               1296.0
# 2021-07-29 01:45:00               1296.0               1066.0
# 2021-07-29 02:00:00               2431.0               1296.0
#
#                      number_of_trades_13  number_of_trades_14  volume_1  \
# open_time
# 2021-07-29 01:00:00               1043.0                878.0   979.050
# 2021-07-29 01:15:00               1295.0               1043.0  1126.414
# 2021-07-29 01:30:00               1521.0               1295.0  1039.405
# 2021-07-29 01:45:00               1296.0               1521.0   561.893
# 2021-07-29 02:00:00               1066.0               1296.0   937.077
#
#                      volume_2  volume_3  volume_4  volume_5  volume_6  \
# open_time
# 2021-07-29 01:00:00   995.638   806.900  1507.497   747.697   683.960
# 2021-07-29 01:15:00   979.050   995.638   806.900  1507.497   747.697
# 2021-07-29 01:30:00  1126.414   979.050   995.638   806.900  1507.497
# 2021-07-29 01:45:00  1039.405  1126.414   979.050   995.638   806.900
# 2021-07-29 02:00:00   561.893  1039.405  1126.414   979.050   995.638
#
#                      volume_7  volume_8  volume_9  volume_10  volume_11  \
# open_time
# 2021-07-29 01:00:00  1518.753   546.335   630.257    642.198    574.671
# 2021-07-29 01:15:00   683.960  1518.753   546.335    630.257    642.198
# 2021-07-29 01:30:00   747.697   683.960  1518.753    546.335    630.257
# 2021-07-29 01:45:00  1507.497   747.697   683.960   1518.753    546.335
# 2021-07-29 02:00:00   806.900  1507.497   747.697    683.960   1518.753
#
#                      volume_12  volume_13  volume_14  quote_asset_volume_1  \
# open_time
# 2021-07-29 01:00:00    560.118    429.314    345.278             56.375548
# 2021-07-29 01:15:00    574.671    560.118    429.314             64.976710
# 2021-07-29 01:30:00    642.198    574.671    560.118             59.982518
# 2021-07-29 01:45:00    630.257    642.198    574.671             32.396800
# 2021-07-29 02:00:00    546.335    630.257    642.198             53.973107
#
#                      quote_asset_volume_2  quote_asset_volume_3  \
# open_time
# 2021-07-29 01:00:00             57.221207             46.305173
# 2021-07-29 01:15:00             56.375548             57.221207
# 2021-07-29 01:30:00             64.976710             56.375548
# 2021-07-29 01:45:00             59.982518             64.976710
# 2021-07-29 02:00:00             32.396800             59.982518
#
#                      quote_asset_volume_4  quote_asset_volume_5  \
# open_time
# 2021-07-29 01:00:00             86.538956             42.982558
# 2021-07-29 01:15:00             46.305173             86.538956
# 2021-07-29 01:30:00             57.221207             46.305173
# 2021-07-29 01:45:00             56.375548             57.221207
# 2021-07-29 02:00:00             64.976710             56.375548
#
#                      quote_asset_volume_6  quote_asset_volume_7  \
# open_time
# 2021-07-29 01:00:00             39.349323             87.376690
# 2021-07-29 01:15:00             42.982558             39.349323
# 2021-07-29 01:30:00             86.538956             42.982558
# 2021-07-29 01:45:00             46.305173             86.538956
# 2021-07-29 02:00:00             57.221207             46.305173
#
#                      quote_asset_volume_8  quote_asset_volume_9  \
# open_time
# 2021-07-29 01:00:00             31.478575             36.328087
# 2021-07-29 01:15:00             87.376690             31.478575
# 2021-07-29 01:30:00             39.349323             87.376690
# 2021-07-29 01:45:00             42.982558             39.349323
# 2021-07-29 02:00:00             86.538956             42.982558
#
#                      quote_asset_volume_10  quote_asset_volume_11  \
# open_time
# 2021-07-29 01:00:00              37.064311              33.123470
# 2021-07-29 01:15:00              36.328087              37.064311
# 2021-07-29 01:30:00              31.478575              36.328087
# 2021-07-29 01:45:00              87.376690              31.478575
# 2021-07-29 02:00:00              39.349323              87.376690
#
#                      quote_asset_volume_12  quote_asset_volume_13  \
# open_time
# 2021-07-29 01:00:00              32.199455              24.657840
# 2021-07-29 01:15:00              33.123470              32.199455
# 2021-07-29 01:30:00              37.064311              33.123470
# 2021-07-29 01:45:00              36.328087              37.064311
# 2021-07-29 02:00:00              31.478575              36.328087
#
#                      quote_asset_volume_14  taker_buy_base_asset_volume_1  \
# open_time
# 2021-07-29 01:00:00              19.832390                        535.796
# 2021-07-29 01:15:00              24.657840                        523.396
# 2021-07-29 01:30:00              32.199455                        595.068
# 2021-07-29 01:45:00              33.123470                        242.236
# 2021-07-29 02:00:00              37.064311                        478.205
#
#                      taker_buy_base_asset_volume_2  \
# open_time
# 2021-07-29 01:00:00                        524.819
# 2021-07-29 01:15:00                        535.796
# 2021-07-29 01:30:00                        523.396
# 2021-07-29 01:45:00                        595.068
# 2021-07-29 02:00:00                        242.236
#
#                      taker_buy_base_asset_volume_3  \
# open_time
# 2021-07-29 01:00:00                        441.570
# 2021-07-29 01:15:00                        524.819
# 2021-07-29 01:30:00                        535.796
# 2021-07-29 01:45:00                        523.396
# 2021-07-29 02:00:00                        595.068
#
#                      taker_buy_base_asset_volume_4  \
# open_time
# 2021-07-29 01:00:00                        610.289
# 2021-07-29 01:15:00                        441.570
# 2021-07-29 01:30:00                        524.819
# 2021-07-29 01:45:00                        535.796
# 2021-07-29 02:00:00                        523.396
#
#                      taker_buy_base_asset_volume_5  \
# open_time
# 2021-07-29 01:00:00                        394.232
# 2021-07-29 01:15:00                        610.289
# 2021-07-29 01:30:00                        441.570
# 2021-07-29 01:45:00                        524.819
# 2021-07-29 02:00:00                        535.796
#
#                      taker_buy_base_asset_volume_6  \
# open_time
# 2021-07-29 01:00:00                        308.405
# 2021-07-29 01:15:00                        394.232
# 2021-07-29 01:30:00                        610.289
# 2021-07-29 01:45:00                        441.570
# 2021-07-29 02:00:00                        524.819
#
#                      taker_buy_base_asset_volume_7  \
# open_time
# 2021-07-29 01:00:00                        648.879
# 2021-07-29 01:15:00                        308.405
# 2021-07-29 01:30:00                        394.232
# 2021-07-29 01:45:00                        610.289
# 2021-07-29 02:00:00                        441.570
#
#                      taker_buy_base_asset_volume_8  \
# open_time
# 2021-07-29 01:00:00                        256.870
# 2021-07-29 01:15:00                        648.879
# 2021-07-29 01:30:00                        308.405
# 2021-07-29 01:45:00                        394.232
# 2021-07-29 02:00:00                        610.289
#
#                      taker_buy_base_asset_volume_9  \
# open_time
# 2021-07-29 01:00:00                        301.569
# 2021-07-29 01:15:00                        256.870
# 2021-07-29 01:30:00                        648.879
# 2021-07-29 01:45:00                        308.405
# 2021-07-29 02:00:00                        394.232
#
#                      taker_buy_base_asset_volume_10  \
# open_time
# 2021-07-29 01:00:00                         308.263
# 2021-07-29 01:15:00                         301.569
# 2021-07-29 01:30:00                         256.870
# 2021-07-29 01:45:00                         648.879
# 2021-07-29 02:00:00                         308.405
#
#                      taker_buy_base_asset_volume_11  \
# open_time
# 2021-07-29 01:00:00                         306.084
# 2021-07-29 01:15:00                         308.263
# 2021-07-29 01:30:00                         301.569
# 2021-07-29 01:45:00                         256.870
# 2021-07-29 02:00:00                         648.879
#
#                      taker_buy_base_asset_volume_12  \
# open_time
# 2021-07-29 01:00:00                         285.654
# 2021-07-29 01:15:00                         306.084
# 2021-07-29 01:30:00                         308.263
# 2021-07-29 01:45:00                         301.569
# 2021-07-29 02:00:00                         256.870
#
#                      taker_buy_base_asset_volume_13  \
# open_time
# 2021-07-29 01:00:00                         165.980
# 2021-07-29 01:15:00                         285.654
# 2021-07-29 01:30:00                         306.084
# 2021-07-29 01:45:00                         308.263
# 2021-07-29 02:00:00                         301.569
#
#                      taker_buy_base_asset_volume_14  \
# open_time
# 2021-07-29 01:00:00                          94.600
# 2021-07-29 01:15:00                         165.980
# 2021-07-29 01:30:00                         285.654
# 2021-07-29 01:45:00                         306.084
# 2021-07-29 02:00:00                         308.263
#
#                      taker_buy_quote_asset_volume_1  \
# open_time
# 2021-07-29 01:00:00                       30.853227
# 2021-07-29 01:15:00                       30.191289
# 2021-07-29 01:30:00                       34.339625
# 2021-07-29 01:45:00                       13.966915
# 2021-07-29 02:00:00                       27.544769
#
#                      taker_buy_quote_asset_volume_2  \
# open_time
# 2021-07-29 01:00:00                       30.161665
# 2021-07-29 01:15:00                       30.853227
# 2021-07-29 01:30:00                       30.191289
# 2021-07-29 01:45:00                       34.339625
# 2021-07-29 02:00:00                       13.966915
#
#                      taker_buy_quote_asset_volume_3  \
# open_time
# 2021-07-29 01:00:00                       25.341036
# 2021-07-29 01:15:00                       30.161665
# 2021-07-29 01:30:00                       30.853227
# 2021-07-29 01:45:00                       30.191289
# 2021-07-29 02:00:00                       34.339625
#
#                      taker_buy_quote_asset_volume_4  \
# open_time
# 2021-07-29 01:00:00                       35.033372
# 2021-07-29 01:15:00                       25.341036
# 2021-07-29 01:30:00                       30.161665
# 2021-07-29 01:45:00                       30.853227
# 2021-07-29 02:00:00                       30.191289
#
#                      taker_buy_quote_asset_volume_5  \
# open_time
# 2021-07-29 01:00:00                       22.661360
# 2021-07-29 01:15:00                       35.033372
# 2021-07-29 01:30:00                       25.341036
# 2021-07-29 01:45:00                       30.161665
# 2021-07-29 02:00:00                       30.853227
#
#                      taker_buy_quote_asset_volume_6  \
# open_time
# 2021-07-29 01:00:00                       17.741498
# 2021-07-29 01:15:00                       22.661360
# 2021-07-29 01:30:00                       35.033372
# 2021-07-29 01:45:00                       25.341036
# 2021-07-29 02:00:00                       30.161665
#
#                      taker_buy_quote_asset_volume_7  \
# open_time
# 2021-07-29 01:00:00                       37.325288
# 2021-07-29 01:15:00                       17.741498
# 2021-07-29 01:30:00                       22.661360
# 2021-07-29 01:45:00                       35.033372
# 2021-07-29 02:00:00                       25.341036
#
#                      taker_buy_quote_asset_volume_8  \
# open_time
# 2021-07-29 01:00:00                       14.799803
# 2021-07-29 01:15:00                       37.325288
# 2021-07-29 01:30:00                       17.741498
# 2021-07-29 01:45:00                       22.661360
# 2021-07-29 02:00:00                       35.033372
#
#                      taker_buy_quote_asset_volume_9  \
# open_time
# 2021-07-29 01:00:00                       17.384825
# 2021-07-29 01:15:00                       14.799803
# 2021-07-29 01:30:00                       37.325288
# 2021-07-29 01:45:00                       17.741498
# 2021-07-29 02:00:00                       22.661360
#
#                      taker_buy_quote_asset_volume_10  \
# open_time
# 2021-07-29 01:00:00                        17.791878
# 2021-07-29 01:15:00                        17.384825
# 2021-07-29 01:30:00                        14.799803
# 2021-07-29 01:45:00                        37.325288
# 2021-07-29 02:00:00                        17.741498
#
#                      taker_buy_quote_asset_volume_11  \
# open_time
# 2021-07-29 01:00:00                        17.642863
# 2021-07-29 01:15:00                        17.791878
# 2021-07-29 01:30:00                        17.384825
# 2021-07-29 01:45:00                        14.799803
# 2021-07-29 02:00:00                        37.325288
#
#                      taker_buy_quote_asset_volume_12  \
# open_time
# 2021-07-29 01:00:00                        16.421018
# 2021-07-29 01:15:00                        17.642863
# 2021-07-29 01:30:00                        17.791878
# 2021-07-29 01:45:00                        17.384825
# 2021-07-29 02:00:00                        14.799803
#
#                      taker_buy_quote_asset_volume_13  \
# open_time
# 2021-07-29 01:00:00                         9.534275
# 2021-07-29 01:15:00                        16.421018
# 2021-07-29 01:30:00                        17.642863
# 2021-07-29 01:45:00                        17.791878
# 2021-07-29 02:00:00                        17.384825
#
#                      taker_buy_quote_asset_volume_14    ma14_1    ma14_2  \
# open_time
# 2021-07-29 01:00:00                         5.433421  0.057578  0.057417
# 2021-07-29 01:15:00                         9.534275  0.057749  0.057578
# 2021-07-29 01:30:00                        16.421018  0.057660  0.057749
# 2021-07-29 01:45:00                        17.642863  0.057693  0.057660
# 2021-07-29 02:00:00                        17.791878  0.057636  0.057693
#
#                        ma14_3    ma14_4    ma14_5    ma14_6    ma14_7  \
# open_time
# 2021-07-29 01:00:00  0.057395  0.057475  0.057531  0.057646  0.057606
# 2021-07-29 01:15:00  0.057417  0.057395  0.057475  0.057531  0.057646
# 2021-07-29 01:30:00  0.057578  0.057417  0.057395  0.057475  0.057531
# 2021-07-29 01:45:00  0.057749  0.057578  0.057417  0.057395  0.057475
# 2021-07-29 02:00:00  0.057660  0.057749  0.057578  0.057417  0.057395
#
#                        ma14_8    ma14_9   ma14_10   ma14_11   ma14_12  \
# open_time
# 2021-07-29 01:00:00  0.057655  0.057633  0.057731  0.057499  0.057462
# 2021-07-29 01:15:00  0.057606  0.057655  0.057633  0.057731  0.057499
# 2021-07-29 01:30:00  0.057646  0.057606  0.057655  0.057633  0.057731
# 2021-07-29 01:45:00  0.057531  0.057646  0.057606  0.057655  0.057633
# 2021-07-29 02:00:00  0.057475  0.057531  0.057646  0.057606  0.057655
#
#                       ma14_13   ma14_14    ma30_1    ma30_2    ma30_3  \
# open_time
# 2021-07-29 01:00:00  0.057432  0.057438  0.057491  0.057408  0.057440
# 2021-07-29 01:15:00  0.057462  0.057432  0.057651  0.057491  0.057408
# 2021-07-29 01:30:00  0.057499  0.057462  0.057701  0.057651  0.057491
# 2021-07-29 01:45:00  0.057731  0.057499  0.057678  0.057701  0.057651
# 2021-07-29 02:00:00  0.057633  0.057731  0.057665  0.057678  0.057701
#
#                        ma30_4    ma30_5    ma30_6    ma30_7    ma30_8  \
# open_time
# 2021-07-29 01:00:00  0.057509  0.057591  0.057626  0.057631  0.057647
# 2021-07-29 01:15:00  0.057440  0.057509  0.057591  0.057626  0.057631
# 2021-07-29 01:30:00  0.057408  0.057440  0.057509  0.057591  0.057626
# 2021-07-29 01:45:00  0.057491  0.057408  0.057440  0.057509  0.057591
# 2021-07-29 02:00:00  0.057651  0.057491  0.057408  0.057440  0.057509
#
#                        ma30_9   ma30_10   ma30_11   ma30_12   ma30_13  \
# open_time
# 2021-07-29 01:00:00  0.057677  0.057605  0.057478  0.057446  0.057434
# 2021-07-29 01:15:00  0.057647  0.057677  0.057605  0.057478  0.057446
# 2021-07-29 01:30:00  0.057631  0.057647  0.057677  0.057605  0.057478
# 2021-07-29 01:45:00  0.057626  0.057631  0.057647  0.057677  0.057605
# 2021-07-29 02:00:00  0.057591  0.057626  0.057631  0.057647  0.057677
#
#                       ma30_14    ma90_1    ma90_2    ma90_3    ma90_4  \
# open_time
# 2021-07-29 01:00:00  0.057421  0.057514  0.057521  0.057557  0.057600
# 2021-07-29 01:15:00  0.057434  0.057531  0.057514  0.057521  0.057557
# 2021-07-29 01:30:00  0.057446  0.057544  0.057531  0.057514  0.057521
# 2021-07-29 01:45:00  0.057478  0.057574  0.057544  0.057531  0.057514
# 2021-07-29 02:00:00  0.057605  0.057607  0.057574  0.057544  0.057531
#
#                        ma90_5    ma90_6    ma90_7    ma90_8    ma90_9  \
# open_time
# 2021-07-29 01:00:00  0.057626  0.057617  0.057587  0.057560  0.057524
# 2021-07-29 01:15:00  0.057600  0.057626  0.057617  0.057587  0.057560
# 2021-07-29 01:30:00  0.057557  0.057600  0.057626  0.057617  0.057587
# 2021-07-29 01:45:00  0.057521  0.057557  0.057600  0.057626  0.057617
# 2021-07-29 02:00:00  0.057514  0.057521  0.057557  0.057600  0.057626
#
#                       ma90_10   ma90_11   ma90_12   ma90_13   ma90_14  \
# open_time
# 2021-07-29 01:00:00  0.057491  0.057443  0.057431  0.057437  0.057426
# 2021-07-29 01:15:00  0.057524  0.057491  0.057443  0.057431  0.057437
# 2021-07-29 01:30:00  0.057560  0.057524  0.057491  0.057443  0.057431
# 2021-07-29 01:45:00  0.057587  0.057560  0.057524  0.057491  0.057443
# 2021-07-29 02:00:00  0.057617  0.057587  0.057560  0.057524  0.057491
#
#                       sup14_1   sup14_2   sup14_3   sup14_4   sup14_5  \
# open_time
# 2021-07-29 01:00:00  0.057365  0.057300  0.057297  0.057297  0.057410
# 2021-07-29 01:15:00  0.057503  0.057365  0.057300  0.057297  0.057297
# 2021-07-29 01:30:00  0.057576  0.057503  0.057365  0.057300  0.057297
# 2021-07-29 01:45:00  0.057597  0.057576  0.057503  0.057365  0.057300
# 2021-07-29 02:00:00  0.057540  0.057597  0.057576  0.057503  0.057365
#
#                       sup14_6   sup14_7   sup14_8   sup14_9  sup14_10  \
# open_time
# 2021-07-29 01:00:00  0.057423  0.057423  0.057569  0.057591  0.057483
# 2021-07-29 01:15:00  0.057410  0.057423  0.057423  0.057569  0.057591
# 2021-07-29 01:30:00  0.057297  0.057410  0.057423  0.057423  0.057569
# 2021-07-29 01:45:00  0.057297  0.057297  0.057410  0.057423  0.057423
# 2021-07-29 02:00:00  0.057300  0.057297  0.057297  0.057410  0.057423
#
#                      sup14_11  sup14_12  sup14_13  sup14_14   sup30_1  \
# open_time
# 2021-07-29 01:00:00  0.057434  0.057400  0.057390  0.057390  0.057297
# 2021-07-29 01:15:00  0.057483  0.057434  0.057400  0.057390  0.057300
# 2021-07-29 01:30:00  0.057591  0.057483  0.057434  0.057400  0.057365
# 2021-07-29 01:45:00  0.057569  0.057591  0.057483  0.057434  0.057503
# 2021-07-29 02:00:00  0.057423  0.057569  0.057591  0.057483  0.057540
#
#                       sup30_2   sup30_3   sup30_4   sup30_5   sup30_6  \
# open_time
# 2021-07-29 01:00:00  0.057297  0.057297  0.057297  0.057410  0.057423
# 2021-07-29 01:15:00  0.057297  0.057297  0.057297  0.057297  0.057410
# 2021-07-29 01:30:00  0.057300  0.057297  0.057297  0.057297  0.057297
# 2021-07-29 01:45:00  0.057365  0.057300  0.057297  0.057297  0.057297
# 2021-07-29 02:00:00  0.057503  0.057365  0.057300  0.057297  0.057297
#
#                       sup30_7   sup30_8   sup30_9  sup30_10  sup30_11  \
# open_time
# 2021-07-29 01:00:00  0.057423  0.057483  0.057434  0.057400  0.057390
# 2021-07-29 01:15:00  0.057423  0.057423  0.057483  0.057434  0.057400
# 2021-07-29 01:30:00  0.057410  0.057423  0.057423  0.057483  0.057434
# 2021-07-29 01:45:00  0.057297  0.057410  0.057423  0.057423  0.057483
# 2021-07-29 02:00:00  0.057297  0.057297  0.057410  0.057423  0.057423
#
#                      sup30_12  sup30_13  sup30_14   sup90_1   sup90_2  \
# open_time
# 2021-07-29 01:00:00  0.057390  0.057307  0.057261  0.057297  0.057297
# 2021-07-29 01:15:00  0.057390  0.057390  0.057307  0.057297  0.057297
# 2021-07-29 01:30:00  0.057400  0.057390  0.057390  0.057297  0.057297
# 2021-07-29 01:45:00  0.057434  0.057400  0.057390  0.057297  0.057297
# 2021-07-29 02:00:00  0.057483  0.057434  0.057400  0.057297  0.057297
#
#                       sup90_3   sup90_4   sup90_5   sup90_6   sup90_7  \
# open_time
# 2021-07-29 01:00:00  0.057297  0.057297  0.057410  0.057400  0.057390
# 2021-07-29 01:15:00  0.057297  0.057297  0.057297  0.057410  0.057400
# 2021-07-29 01:30:00  0.057297  0.057297  0.057297  0.057297  0.057410
# 2021-07-29 01:45:00  0.057297  0.057297  0.057297  0.057297  0.057297
# 2021-07-29 02:00:00  0.057297  0.057297  0.057297  0.057297  0.057297
#
#                       sup90_8   sup90_9  sup90_10  sup90_11  sup90_12  \
# open_time
# 2021-07-29 01:00:00  0.057390  0.057307  0.057261  0.057261  0.057261
# 2021-07-29 01:15:00  0.057390  0.057390  0.057307  0.057261  0.057261
# 2021-07-29 01:30:00  0.057400  0.057390  0.057390  0.057307  0.057261
# 2021-07-29 01:45:00  0.057410  0.057400  0.057390  0.057390  0.057307
# 2021-07-29 02:00:00  0.057297  0.057410  0.057400  0.057390  0.057390
#
#                      sup90_13  sup90_14  ...     atr_3     atr_4     atr_5  \
# open_time                                ...
# 2021-07-29 01:00:00  0.057168  0.057089  ...  0.000167  0.000182  0.000178
# 2021-07-29 01:15:00  0.057261  0.057168  ...  0.000170  0.000167  0.000182
# 2021-07-29 01:30:00  0.057261  0.057261  ...  0.000167  0.000170  0.000167
# 2021-07-29 01:45:00  0.057261  0.057261  ...  0.000166  0.000167  0.000170
# 2021-07-29 02:00:00  0.057307  0.057261  ...  0.000164  0.000166  0.000167
#
#                         atr_6     atr_7     atr_8     atr_9    atr_10  \
# open_time
# 2021-07-29 01:00:00  0.000193  0.000205  0.000217  0.000217  0.000238
# 2021-07-29 01:15:00  0.000178  0.000193  0.000205  0.000217  0.000217
# 2021-07-29 01:30:00  0.000182  0.000178  0.000193  0.000205  0.000217
# 2021-07-29 01:45:00  0.000167  0.000182  0.000178  0.000193  0.000205
# 2021-07-29 02:00:00  0.000170  0.000167  0.000182  0.000178  0.000193
#
#                        atr_11    atr_12    atr_13    atr_14  atr_diff_1  \
# open_time
# 2021-07-29 01:00:00  0.000247  0.000256  0.000268  0.000279   -0.000003
# 2021-07-29 01:15:00  0.000238  0.000247  0.000256  0.000268   -0.000002
# 2021-07-29 01:30:00  0.000217  0.000238  0.000247  0.000256   -0.000001
# 2021-07-29 01:45:00  0.000217  0.000217  0.000238  0.000247    0.000012
# 2021-07-29 02:00:00  0.000205  0.000217  0.000217  0.000238    0.000006
#
#                      atr_diff_2  atr_diff_3  atr_diff_4  atr_diff_5  \
# open_time
# 2021-07-29 01:00:00    0.000003   -0.000015    0.000004   -0.000015
# 2021-07-29 01:15:00   -0.000003    0.000003   -0.000015    0.000004
# 2021-07-29 01:30:00   -0.000002   -0.000003    0.000003   -0.000015
# 2021-07-29 01:45:00   -0.000001   -0.000002   -0.000003    0.000003
# 2021-07-29 02:00:00    0.000012   -0.000001   -0.000002   -0.000003
#
#                      atr_diff_6  atr_diff_7    atr_diff_8    atr_diff_9  \
# open_time
# 2021-07-29 01:00:00   -0.000011   -0.000013  9.285714e-07 -2.178571e-05
# 2021-07-29 01:15:00   -0.000015   -0.000011 -1.257143e-05  9.285714e-07
# 2021-07-29 01:30:00    0.000004   -0.000015 -1.142857e-05 -1.257143e-05
# 2021-07-29 01:45:00   -0.000015    0.000004 -1.507143e-05 -1.142857e-05
# 2021-07-29 02:00:00    0.000003   -0.000015  4.142857e-06 -1.507143e-05
#
#                       atr_diff_10   atr_diff_11   atr_diff_12  atr_diff_13  \
# open_time
# 2021-07-29 01:00:00 -8.642857e-06 -9.000000e-06 -1.221429e-05    -0.000010
# 2021-07-29 01:15:00 -2.178571e-05 -8.642857e-06 -9.000000e-06    -0.000012
# 2021-07-29 01:30:00  9.285714e-07 -2.178571e-05 -8.642857e-06    -0.000009
# 2021-07-29 01:45:00 -1.257143e-05  9.285714e-07 -2.178571e-05    -0.000009
# 2021-07-29 02:00:00 -1.142857e-05 -1.257143e-05  9.285714e-07    -0.000022
#
#                      atr_diff_14  atr_ma14_1  atr_ma14_2  atr_ma14_3  \
# open_time
# 2021-07-29 01:00:00    -0.000009    0.000213    0.000222    0.000230
# 2021-07-29 01:15:00    -0.000010    0.000205    0.000213    0.000222
# 2021-07-29 01:30:00    -0.000012    0.000198    0.000205    0.000213
# 2021-07-29 01:45:00    -0.000009    0.000192    0.000198    0.000205
# 2021-07-29 02:00:00    -0.000009    0.000186    0.000192    0.000198
#
#                      atr_ma14_4  atr_ma14_5  atr_ma14_6  atr_ma14_7  \
# open_time
# 2021-07-29 01:00:00    0.000238    0.000247    0.000254    0.000261
# 2021-07-29 01:15:00    0.000230    0.000238    0.000247    0.000254
# 2021-07-29 01:30:00    0.000222    0.000230    0.000238    0.000247
# 2021-07-29 01:45:00    0.000213    0.000222    0.000230    0.000238
# 2021-07-29 02:00:00    0.000205    0.000213    0.000222    0.000230
#
#                      atr_ma14_8  atr_ma14_9  atr_ma14_10  atr_ma14_11  \
# open_time
# 2021-07-29 01:00:00    0.000266    0.000268     0.000270     0.000269
# 2021-07-29 01:15:00    0.000261    0.000266     0.000268     0.000270
# 2021-07-29 01:30:00    0.000254    0.000261     0.000266     0.000268
# 2021-07-29 01:45:00    0.000247    0.000254     0.000261     0.000266
# 2021-07-29 02:00:00    0.000238    0.000247     0.000254     0.000261
#
#                      atr_ma14_12  atr_ma14_13  atr_ma14_14      rsi_1  \
# open_time
# 2021-07-29 01:00:00     0.000267     0.000266     0.000261  40.495695
# 2021-07-29 01:15:00     0.000269     0.000267     0.000266  65.783100
# 2021-07-29 01:30:00     0.000270     0.000269     0.000267  37.933106
# 2021-07-29 01:45:00     0.000268     0.000270     0.000269  66.825027
# 2021-07-29 02:00:00     0.000266     0.000268     0.000270  36.476762
#
#                          rsi_2      rsi_3      rsi_4      rsi_5      rsi_6  \
# open_time
# 2021-07-29 01:00:00  60.213575  33.875680  59.834147  35.918880  62.317466
# 2021-07-29 01:15:00  40.495695  60.213575  33.875680  59.834147  35.918880
# 2021-07-29 01:30:00  65.783100  40.495695  60.213575  33.875680  59.834147
# 2021-07-29 01:45:00  37.933106  65.783100  40.495695  60.213575  33.875680
# 2021-07-29 02:00:00  66.825027  37.933106  65.783100  40.495695  60.213575
#
#                          rsi_7      rsi_8      rsi_9     rsi_10     rsi_11  \
# open_time
# 2021-07-29 01:00:00  38.898781  60.865112  40.389126  60.096128  43.308489
# 2021-07-29 01:15:00  62.317466  38.898781  60.865112  40.389126  60.096128
# 2021-07-29 01:30:00  35.918880  62.317466  38.898781  60.865112  40.389126
# 2021-07-29 01:45:00  59.834147  35.918880  62.317466  38.898781  60.865112
# 2021-07-29 02:00:00  33.875680  59.834147  35.918880  62.317466  38.898781
#
#                         rsi_12     rsi_13     rsi_14  rsi_diff_1  rsi_diff_2  \
# open_time
# 2021-07-29 01:00:00  51.993849  42.631088  50.885494  -19.717880   26.337895
# 2021-07-29 01:15:00  43.308489  51.993849  42.631088   25.287404  -19.717880
# 2021-07-29 01:30:00  60.096128  43.308489  51.993849  -27.849994   25.287404
# 2021-07-29 01:45:00  40.389126  60.096128  43.308489   28.891921  -27.849994
# 2021-07-29 02:00:00  60.865112  40.389126  60.096128  -30.348264   28.891921
#
#                      rsi_diff_3  rsi_diff_4  rsi_diff_5  rsi_diff_6  \
# open_time
# 2021-07-29 01:00:00  -25.958467   23.915267  -26.398586   23.418684
# 2021-07-29 01:15:00   26.337895  -25.958467   23.915267  -26.398586
# 2021-07-29 01:30:00  -19.717880   26.337895  -25.958467   23.915267
# 2021-07-29 01:45:00   25.287404  -19.717880   26.337895  -25.958467
# 2021-07-29 02:00:00  -27.849994   25.287404  -19.717880   26.337895
#
#                      rsi_diff_7  rsi_diff_8  rsi_diff_9  rsi_diff_10  \
# open_time
# 2021-07-29 01:00:00  -21.966331   20.475986  -19.707002    16.787639
# 2021-07-29 01:15:00   23.418684  -21.966331   20.475986   -19.707002
# 2021-07-29 01:30:00  -26.398586   23.418684  -21.966331    20.475986
# 2021-07-29 01:45:00   23.915267  -26.398586   23.418684   -21.966331
# 2021-07-29 02:00:00  -25.958467   23.915267  -26.398586    23.418684
#
#                      rsi_diff_11  rsi_diff_12  rsi_diff_13  rsi_diff_14  \
# open_time
# 2021-07-29 01:00:00    -8.685361     9.362761    -8.254405     8.029165
# 2021-07-29 01:15:00    16.787639    -8.685361     9.362761    -8.254405
# 2021-07-29 01:30:00   -19.707002    16.787639    -8.685361     9.362761
# 2021-07-29 01:45:00    20.475986   -19.707002    16.787639    -8.685361
# 2021-07-29 02:00:00   -21.966331    20.475986   -19.707002    16.787639
#
#                      rsi_ma14_1  rsi_ma14_2  rsi_ma14_3  rsi_ma14_4  \
# open_time
# 2021-07-29 01:00:00   48.694536   48.863153   48.099619   48.842819
# 2021-07-29 01:15:00   49.758651   48.694536   48.863153   48.099619
# 2021-07-29 01:30:00   49.423081   49.758651   48.694536   48.863153
# 2021-07-29 01:45:00   50.482451   49.423081   49.758651   48.694536
# 2021-07-29 02:00:00   49.994470   50.482451   49.423081   49.758651
#
#                      rsi_ma14_5  rsi_ma14_6  rsi_ma14_7  rsi_ma14_8  \
# open_time
# 2021-07-29 01:00:00   47.829681   48.775916   47.319922   47.503189
# 2021-07-29 01:15:00   48.842819   47.829681   48.775916   47.319922
# 2021-07-29 01:30:00   48.099619   48.842819   47.829681   48.775916
# 2021-07-29 01:45:00   48.863153   48.099619   48.842819   47.829681
# 2021-07-29 02:00:00   48.694536   48.863153   48.099619   48.842819
#
#                      rsi_ma14_9  rsi_ma14_10  rsi_ma14_11  rsi_ma14_12  \
# open_time
# 2021-07-29 01:00:00   46.309931    46.675353    45.709518    45.520235
# 2021-07-29 01:15:00   47.503189    46.309931    46.675353    45.709518
# 2021-07-29 01:30:00   47.319922    47.503189    46.309931    46.675353
# 2021-07-29 01:45:00   48.775916    47.319922    47.503189    46.309931
# 2021-07-29 02:00:00   47.829681    48.775916    47.319922    47.503189
#
#                      rsi_ma14_13  rsi_ma14_14  trend_up_1  trend_up_2  \
# open_time
# 2021-07-29 01:00:00    45.483538    46.056237        True        True
# 2021-07-29 01:15:00    45.520235    45.483538       False        True
# 2021-07-29 01:30:00    45.709518    45.520235        True       False
# 2021-07-29 01:45:00    46.675353    45.709518       False        True
# 2021-07-29 02:00:00    46.309931    46.675353       False       False
#
#                      trend_up_3  trend_up_4  trend_up_5  trend_up_6  \
# open_time
# 2021-07-29 01:00:00        True       False       False       False
# 2021-07-29 01:15:00        True        True       False       False
# 2021-07-29 01:30:00        True        True        True       False
# 2021-07-29 01:45:00       False        True        True        True
# ...
# open_time
# 2021-07-29 01:00:00         True         True         True        False
# 2021-07-29 01:15:00        False         True         True         True
# 2021-07-29 01:30:00         True        False         True         True
# 2021-07-29 01:45:00        False         True        False         True
# 2021-07-29 02:00:00        False        False         True        False
#
#                      trend_up3_5  trend_up3_6  trend_up3_7  trend_up3_8  \
# open_time
# 2021-07-29 01:00:00        False        False         True        False
# 2021-07-29 01:15:00        False        False        False         True
# 2021-07-29 01:30:00         True        False        False        False
# 2021-07-29 01:45:00         True         True        False        False
# 2021-07-29 02:00:00         True         True         True        False
#
#                      trend_up3_9  trend_up3_10  trend_up3_11  trend_up3_12  \
# open_time
# 2021-07-29 01:00:00         True         False          True          True
# 2021-07-29 01:15:00        False          True         False          True
# 2021-07-29 01:30:00         True         False          True         False
# 2021-07-29 01:45:00        False          True         False          True
# 2021-07-29 02:00:00        False         False          True         False
#
#                      trend_up3_13  trend_up3_14  trend_up14_1  trend_up14_2  \
# open_time
# 2021-07-29 01:00:00          True         False          True          True
# 2021-07-29 01:15:00          True          True         False          True
# 2021-07-29 01:30:00          True          True          True         False
# 2021-07-29 01:45:00         False          True         False          True
# 2021-07-29 02:00:00          True         False         False         False
#
#                      trend_up14_3  trend_up14_4  trend_up14_5  trend_up14_6  \
# open_time
# 2021-07-29 01:00:00          True         False         False         False
# 2021-07-29 01:15:00          True          True         False         False
# 2021-07-29 01:30:00          True          True          True         False
# 2021-07-29 01:45:00         False          True          True          True
# 2021-07-29 02:00:00          True         False          True          True
#
#                      trend_up14_7  trend_up14_8  trend_up14_9  trend_up14_10  \
# open_time
# 2021-07-29 01:00:00          True         False          True          False
# 2021-07-29 01:15:00         False          True         False           True
# 2021-07-29 01:30:00         False         False          True          False
# 2021-07-29 01:45:00         False         False         False           True
# 2021-07-29 02:00:00          True         False         False          False
#
#                      trend_up14_11  trend_up14_12  trend_up14_13  \
# open_time
# 2021-07-29 01:00:00           True           True           True
# 2021-07-29 01:15:00          False           True           True
# 2021-07-29 01:30:00           True          False           True
# 2021-07-29 01:45:00          False           True          False
# 2021-07-29 02:00:00           True          False           True
#
#                      trend_up14_14  trend_up30_1  trend_up30_2 trend_up30_3  \
# open_time
# 2021-07-29 01:00:00          False          True          True        False
# 2021-07-29 01:15:00           True          True          True         True
# 2021-07-29 01:30:00           True          True          True         True
# 2021-07-29 01:45:00           True         False          True         True
# 2021-07-29 02:00:00          False         False         False         True
#
#                     trend_up30_4 trend_up30_5 trend_up30_6 trend_up30_7  \
# open_time
# 2021-07-29 01:00:00        False        False        False         True
# 2021-07-29 01:15:00        False        False        False        False
# 2021-07-29 01:30:00         True        False        False        False
# 2021-07-29 01:45:00         True         True        False        False
# 2021-07-29 02:00:00         True         True         True        False
#
#                     trend_up30_8 trend_up30_9 trend_up30_10 trend_up30_11  \
# open_time
# 2021-07-29 01:00:00        False         True          True          True
# 2021-07-29 01:15:00         True        False          True          True
# 2021-07-29 01:30:00        False         True         False          True
# 2021-07-29 01:45:00        False        False          True         False
# 2021-07-29 02:00:00        False        False         False          True
#
#                     trend_up30_12 trend_up30_13 trend_up30_14 cs_ss_1 cs_ss_2  \
# open_time
# 2021-07-29 01:00:00          True          True         False   False   False
# 2021-07-29 01:15:00          True          True          True   False   False
# 2021-07-29 01:30:00          True          True          True   False   False
# 2021-07-29 01:45:00          True          True          True   False   False
# 2021-07-29 02:00:00         False          True          True   False   False
#
#                     cs_ss_3 cs_ss_4 cs_ss_5 cs_ss_6 cs_ss_7 cs_ss_8 cs_ss_9  \
# open_time
# 2021-07-29 01:00:00   False   False   False   False   False   False   False
# 2021-07-29 01:15:00   False   False   False   False   False   False   False
# 2021-07-29 01:30:00   False   False   False   False   False   False   False
# 2021-07-29 01:45:00   False   False   False   False   False   False   False
# 2021-07-29 02:00:00   False   False   False   False   False   False   False
#
#                     cs_ss_10 cs_ss_11 cs_ss_12 cs_ss_13 cs_ss_14 cs_ssr_1  \
# open_time
# 2021-07-29 01:00:00    False    False     True    False     True    False
# 2021-07-29 01:15:00    False    False    False     True    False    False
# 2021-07-29 01:30:00    False    False    False    False     True    False
# 2021-07-29 01:45:00    False    False    False    False    False    False
# 2021-07-29 02:00:00    False    False    False    False    False    False
#
#                     cs_ssr_2 cs_ssr_3 cs_ssr_4 cs_ssr_5 cs_ssr_6 cs_ssr_7  \
# open_time
# 2021-07-29 01:00:00    False    False    False    False    False    False
# 2021-07-29 01:15:00    False    False    False    False    False    False
# 2021-07-29 01:30:00    False    False    False    False    False    False
# 2021-07-29 01:45:00    False    False    False    False    False    False
# 2021-07-29 02:00:00    False    False    False    False    False    False
#
#                     cs_ssr_8 cs_ssr_9 cs_ssr_10 cs_ssr_11 cs_ssr_12 cs_ssr_13  \
# open_time
# 2021-07-29 01:00:00    False    False     False     False     False     False
# 2021-07-29 01:15:00    False    False     False     False     False     False
# 2021-07-29 01:30:00    False    False     False     False     False     False
# 2021-07-29 01:45:00    False    False     False     False     False     False
# 2021-07-29 02:00:00    False    False     False     False     False     False
#
#                     cs_ssr_14 cs_hm_1 cs_hm_2 cs_hm_3 cs_hm_4 cs_hm_5 cs_hm_6  \
# open_time
# 2021-07-29 01:00:00     False   False   False   False   False   False   False
# 2021-07-29 01:15:00     False   False   False   False   False   False   False
# 2021-07-29 01:30:00     False   False   False   False   False   False   False
# 2021-07-29 01:45:00     False   False   False   False   False   False   False
# 2021-07-29 02:00:00     False   False   False   False   False   False   False
#
#                     cs_hm_7 cs_hm_8 cs_hm_9 cs_hm_10 cs_hm_11 cs_hm_12  \
# open_time
# 2021-07-29 01:00:00   False   False   False    False    False    False
# 2021-07-29 01:15:00   False   False   False    False    False    False
# 2021-07-29 01:30:00   False   False   False    False    False    False
# 2021-07-29 01:45:00   False   False   False    False    False    False
# 2021-07-29 02:00:00   False   False   False    False    False    False
#
#                     cs_hm_13 cs_hm_14 cs_hmr_1 cs_hmr_2 cs_hmr_3 cs_hmr_4  \
# open_time
# 2021-07-29 01:00:00    False    False    False    False    False    False
# 2021-07-29 01:15:00    False    False    False    False    False    False
# 2021-07-29 01:30:00    False    False    False    False    False    False
# 2021-07-29 01:45:00    False    False    False    False    False    False
# 2021-07-29 02:00:00    False    False    False    False    False    False
#
#                     cs_hmr_5 cs_hmr_6 cs_hmr_7 cs_hmr_8 cs_hmr_9 cs_hmr_10  \
# open_time
# 2021-07-29 01:00:00    False    False     True    False    False     False
# 2021-07-29 01:15:00    False    False    False     True    False     False
# 2021-07-29 01:30:00    False    False    False    False     True     False
# 2021-07-29 01:45:00    False    False    False    False    False      True
# 2021-07-29 02:00:00    False    False    False    False    False     False
#
#                     cs_hmr_11 cs_hmr_12 cs_hmr_13 cs_hmr_14 cs_brh_1 cs_brh_2  \
# open_time
# 2021-07-29 01:00:00     False     False     False     False    False    False
# 2021-07-29 01:15:00     False     False     False     False    False    False
# 2021-07-29 01:30:00     False     False     False     False    False    False
# 2021-07-29 01:45:00     False     False     False     False    False    False
# 2021-07-29 02:00:00      True     False     False     False    False    False
#
#                     cs_brh_3 cs_brh_4 cs_brh_5 cs_brh_6 cs_brh_7 cs_brh_8  \
# open_time
# 2021-07-29 01:00:00    False    False    False    False    False    False
# 2021-07-29 01:15:00    False    False    False    False    False    False
# 2021-07-29 01:30:00    False    False    False    False    False    False
# 2021-07-29 01:45:00    False    False    False    False    False    False
# 2021-07-29 02:00:00    False    False    False    False    False    False
#
#                     cs_brh_9 cs_brh_10 cs_brh_11 cs_brh_12 cs_brh_13  \
# open_time
# 2021-07-29 01:00:00    False     False     False     False     False
# 2021-07-29 01:15:00    False     False     False     False     False
# 2021-07-29 01:30:00    False     False     False     False     False
# 2021-07-29 01:45:00    False     False     False     False     False
# 2021-07-29 02:00:00    False     False     False     False     False
#
#                     cs_brh_14 cs_buh_1 cs_buh_2 cs_buh_3 cs_buh_4 cs_buh_5  \
# open_time
# 2021-07-29 01:00:00     False    False    False    False    False    False
# 2021-07-29 01:15:00     False    False    False    False    False    False
# 2021-07-29 01:30:00     False    False    False    False    False    False
# 2021-07-29 01:45:00     False    False    False    False    False    False
# 2021-07-29 02:00:00     False    False    False    False    False    False
#
#                     cs_buh_6 cs_buh_7 cs_buh_8 cs_buh_9 cs_buh_10 cs_buh_11  \
# open_time
# 2021-07-29 01:00:00    False    False    False    False     False     False
# 2021-07-29 01:15:00    False    False    False    False     False     False
# 2021-07-29 01:30:00    False    False    False    False     False     False
# 2021-07-29 01:45:00    False    False    False    False     False     False
# 2021-07-29 02:00:00    False    False    False    False     False     False
#
#                     cs_buh_12 cs_buh_13 cs_buh_14 cs_ebu_1 cs_ebu_2 cs_ebu_3  \
# open_time
# 2021-07-29 01:00:00     False     False     False    False    False    False
# 2021-07-29 01:15:00     False     False     False    False    False    False
# 2021-07-29 01:30:00     False     False     False    False    False    False
# 2021-07-29 01:45:00     False     False     False    False    False    False
# 2021-07-29 02:00:00     False     False     False    False    False    False
#
#                     cs_ebu_4 cs_ebu_5 cs_ebu_6 cs_ebu_7 cs_ebu_8 cs_ebu_9  \
# open_time
# 2021-07-29 01:00:00    False    False    False    False    False    False
# 2021-07-29 01:15:00    False    False    False    False    False    False
# 2021-07-29 01:30:00    False    False    False    False    False    False
# 2021-07-29 01:45:00    False    False    False    False    False    False
# 2021-07-29 02:00:00    False    False    False    False    False    False
#
#                     cs_ebu_10 cs_ebu_11 cs_ebu_12 cs_ebu_13 cs_ebu_14  \
# open_time
# 2021-07-29 01:00:00     False     False     False     False     False
# 2021-07-29 01:15:00     False     False     False     False     False
# 2021-07-29 01:30:00     False     False     False     False     False
# 2021-07-29 01:45:00     False     False     False     False     False
# 2021-07-29 02:00:00     False     False     False     False     False
#
#                     cs_ebr_1 cs_ebr_2 cs_ebr_3 cs_ebr_4 cs_ebr_5 cs_ebr_6  \
# open_time
# 2021-07-29 01:00:00    False    False    False    False    False    False
# 2021-07-29 01:15:00    False    False    False    False    False    False
# 2021-07-29 01:30:00    False    False    False    False    False    False
# 2021-07-29 01:45:00    False    False    False    False    False    False
# 2021-07-29 02:00:00    False    False    False    False    False    False
#
#                     cs_ebr_7 cs_ebr_8 cs_ebr_9 cs_ebr_10 cs_ebr_11 cs_ebr_12  \
# open_time
# 2021-07-29 01:00:00    False    False    False     False     False     False
# 2021-07-29 01:15:00    False    False    False     False     False     False
# 2021-07-29 01:30:00    False    False    False     False     False     False
# 2021-07-29 01:45:00    False    False    False     False     False     False
# 2021-07-29 02:00:00    False    False    False     False     False     False
#
#                     cs_ebr_13 cs_ebr_14
# open_time
# 2021-07-29 01:00:00     False     False
# 2021-07-29 01:15:00     False     False
# 2021-07-29 01:30:00     False     False
# 2021-07-29 01:45:00     False     False
# 2021-07-29 02:00:00     False     False
#
# [5 rows x 544 columns]

# %%
df.shape
# Out:
# (141189, 544)

# %%
mc = mpf.make_marketcolors(up='g',down='r',
                           edge='black',
                           volume='gray')
s  = mpf.make_mpf_style(marketcolors=mc)

# %%
mpf.plot(df[-40:],
         type='candlestick',
         volume=True, title='ETHBTC - 15 min',
         #style=s,
         #mav=(3,6,9)
        )

# %% [markdown]
# Simple experiment of the `mplfinance` library to see how candlestick charts can be generated with varying features.

# %%
df2 = pd.read_csv('data/0_klines_ETHBTC_1d.csv', parse_dates=['open_time', 'close_time'])
df2.set_index('open_time', inplace=True)
df2.sort_index(inplace=True)
df2.tail()
# Out:
#                                open      high       low     close      volume  \
# open_time
# 2021-06-26 00:00:00+00:00  0.057288  0.057564  0.056010  0.056677  151322.259
# 2021-06-27 00:00:00+00:00  0.056677  0.057327  0.055205  0.057123  148346.997
# 2021-06-28 00:00:00+00:00  0.057124  0.061997  0.056941  0.060431  244052.889
# 2021-06-29 00:00:00+00:00  0.060424  0.061997  0.060157  0.060289  158986.833
# 2021-06-30 00:00:00+00:00  0.060298  0.065502  0.059968  0.064932  160059.633
#
#                                        close_time  quote_asset_volume  \
# open_time
# 2021-06-26 00:00:00+00:00 2021-06-26 23:59:59.999         8589.077944
# 2021-06-27 00:00:00+00:00 2021-06-27 23:59:59.999         8320.982320
# 2021-06-28 00:00:00+00:00 2021-06-28 23:59:59.999        14486.849371
# 2021-06-29 00:00:00+00:00 2021-06-29 23:59:59.999         9709.457856
# 2021-06-30 00:00:00+00:00 2021-06-30 23:59:59.999         9965.297796
#
#                            number_of_trades  taker_buy_base_asset_volume  \
# open_time
# 2021-06-26 00:00:00+00:00            198614                    71097.328
# 2021-06-27 00:00:00+00:00            190465                    77979.092
# 2021-06-28 00:00:00+00:00            299056                   113679.239
# 2021-06-29 00:00:00+00:00            228429                    67921.734
# 2021-06-30 00:00:00+00:00            237167                    77125.476
#
#                            taker_buy_quote_asset_volume  pair_id
# open_time
# 2021-06-26 00:00:00+00:00                   4037.061382        0
# 2021-06-27 00:00:00+00:00                   4370.699602        0
# 2021-06-28 00:00:00+00:00                   6748.950922        0
# 2021-06-29 00:00:00+00:00                   4147.486548        0
# 2021-06-30 00:00:00+00:00                   4798.351143        0

# %%
retvals = {}
mpf.plot(df2[-100:],
         type='candlestick',
         volume=True, title='ETHBTC - 1 Day',
         mav=(3,14,30),
         return_calculated_values=retvals
        )

# %%
retvals = {}
mpf.plot(df2[-100:],
         type='renko',  # This is used to get the ATR values
         mav=(8,20,30),
         volume=True,
         figratio=(10,8),
         figscale=1.5,
         style=s,
         renko_params=dict(brick_size='atr', atr_length=2),
         return_calculated_values=retvals
        )

# %% [markdown]
# They call this a "renko" chart which is built using the ATR (Average True Range) of the price to get a feel for the market momentum.

# %% [markdown]
# # Feature Engineering
#
# This has all been integrated into AWS

# %%
# def add_lookback_trades(df, levels=1, cols=['open','high','low','close']):
#     '''
#     Adds [cols] columns for previous records to each row. New columns are
#     suffixed with the record backstep. For example: open_1 means the open
#     price 1 record back.
#     '''
#     new_df = df.copy()
#     for l in range(1,levels+1):
#         new_cols={c:f'{c}_{l}' for c in cols}
#         new_df = new_df.merge(df[cols].shift(l).bfill().rename(columns=new_cols),
#                               how='left', left_index=True, right_index=True)
#     return new_df

# def add_lookforward_trades(df, levels=1, cols=['open','high','low','close']):
#     '''
#     Adds [cols] columns for future records to each row. New columns are
#     suffixed with the record forwardstep. For example: open_1 means the open
#     price 1 record forward.
#     '''
#     new_df = df.copy()
#     for l in range(1,levels+1):
#         new_cols={c:f'{c}_{l}' for c in cols}
#         new_df = new_df.merge(df[cols].shift(-l).ffill().rename(columns=new_cols),
#                               how='left', left_index=True, right_index=True)
#     return new_df

# def calculate_ma(df, period=14, field='close'):
#     '''
#     Calculate Moving Average
#     '''
#     df2=df[[field]].copy()
#     return df2.rolling(period, min_periods=1).mean()

# def calculate_atr(df, period=14):
#     '''
#     Calculate the Average True Range (ATR)
#     '''
#     df2=df[['high','low','close_1']].copy()
#     #df2=add_lookback_trades(df2,1,['high','low','close'])
#     #df2['tr_calc'] = np.max([df2.high-df2.low, np.abs(df2.high-df2.close_1), np.abs(df2.low-df2.close_1)], axis=0)
#     df2['tr_calc'] = np.max([df2.high, df2.close_1], axis=0) - np.min([df2.low, df2.close_1], axis=0)
#     return df2.tr_calc.rolling(period, min_periods=1).mean()

# def calculate_rsi(df, period=14, field='close'):
#     '''
#     Calculate Relative Stength Indicator (RSI)
#     Source: https://www.learnpythonwithrune.org/pandas-calculate-the-relative-strength-index-rsi-on-a-stock/
#     '''
#     df2=df[[field]].copy()
#     delta = df2.close.diff()
#     up = delta.clip(lower=0)
#     down = -1*delta.clip(upper=0)
#     ema_up = up.ewm(com=period-1, adjust=False).mean()
#     ema_down = down.ewm(com=period-1, adjust=False).mean()
#     rs = ema_up/ema_down
#     rs[0] = 0 # backfill with 0
#     return 100 - (100/(1 + rs))

# def calculate_upward_trend(df, period):
#     '''
#     Calculates if trend is going up based on moving average being
#     negative or positive
#     '''
#     trend = calculate_ma(df, period).diff()
#     return np.where(trend.close.to_numpy()>0,True,False)


# def calculate_support_and_resistence_levels(df, periods=(14,30,90), levels=3):
#     '''
#     Calculate the levels of support and resistence.  Support is the min
#     value for each period and Resistence is the max.  The look-back
#     parameter "levels" adds previous levels to each row.
#     '''
#     new_df = df.copy()
#     if type(periods) not in (int,tuple,list):
#         raise Exception('periods must be an int, tuple or list')
    
#     if type(periods) == int:
#         periods = [periods]
        
#     for period in periods:
#         new_df[f'res{period}'] = new_df.high.rolling(period,min_periods=1).max()
#         new_df[f'sup{period}'] = new_df.low.rolling(period,min_periods=1).min()
    
#         # Add the previous levels of support and resistence
#         # NOTE: if the same resistence or support level exists occurs out of sequence
#         # then the prevous level will be based on the first occurence.
#         # For example, given support levels    0.75, 0.75, 0.91, 0.69, 0.69, 0.91. (0.91 duplicated)
#         # the previous support levels would be 0.75, 0.75, 0.75, 0.91, 0.91, *0.75*
#         ru = new_df[f'res{period}'].unique()
#         su = new_df[f'sup{period}'].unique()
#         for level in range(1,levels+1):
#             prev_ru = pd.Series(ru).shift(level).bfill().to_list()
#             prev_su = pd.Series(su).shift(level).bfill().to_list()
#             new_df[f'res{period}_{level}'] = new_df[f'res{period}'].apply(lambda x: prev_ru[np.where(ru==x)[0][0]])
#             new_df[f'sup{period}_{level}'] = new_df[f'sup{period}'].apply(lambda x: prev_su[np.where(su==x)[0][0]])
#     return new_df

# def cs_shooting_star(x):
#     '''
#     Source: https://en.wikipedia.org/wiki/Shooting_star_(candlestick_pattern)
#     '''
#     if x.open > x.close: return False
#     s=x.high-x.low
#     t=x.low+s*0.382  # Fibonacci Ratio - Retracement Level
#     if t>=x.close: return True
#     else: return False

# def cs_shooting_star_R(x):
#     '''
#     Source: https://en.wikipedia.org/wiki/Shooting_star_(candlestick_pattern)
#     '''
#     if x.open <= x.close: return False
#     s=x.high-x.low
#     t=x.low+s*0.382  # Fibonacci Ratio - Retracement Level
#     if t>=x.open: return True
#     else: return False

# def cs_hammer(x):
#     '''
#     Source: https://en.wikipedia.org/wiki/Hammer_(candlestick_pattern)
#     '''
#     if x.open < x.close: return False
#     s=x.high-x.low
#     t=x.high-s*0.382  # Fibonacci Ratio - Retracement Level
#     if t<=x.close: return True
#     else: return False
    
# def cs_hammer_R(x):
#     '''
#     Source: https://en.wikipedia.org/wiki/Hammer_(candlestick_pattern)
#     '''
#     if x.open >= x.close: return False
#     s=x.high-x.low
#     t=x.high-s*0.382  # Fibonacci Ratio - Retracement Level
#     if t<=x.open: return True
#     else: return False
    
# def cs_bearish_harami(x, complete=False):
#     '''
#     The body of the right candle stick must fit inside
#     the body of the left candle stick.
#     Source: https://www.investopedia.com/terms/b/bearishharami.asp
#     '''
#     if x.open > x.close and \
#        x.open_1 < x.close_1 and \
#        x.close_1 >= x.open and x.open_1 <= x.close and \
#        x.high_1 >= x.high and x.low_1 <= x.low:
#         return True
#     else:
#         return False

# def cs_bullish_harami(x):
#     '''
#     The body of the right candle stick must fit inside
#     the body of the left candle stick.
#     Source: https://www.investopedia.com/terms/b/bullishharami.asp
#     '''
#     if x.open < x.close and \
#        x.open_1 > x.close_1 and \
#        x.close_1 <= x.open and x.open_1 >= x.close and \
#        x.high_1 >= x.high and x.low_1 <= x.low:
#         return True
#     else:
#         return False

# def cs_engulfing_bullish(x):
#     '''
#     The body of the left candle stick must fit inside
#     the body of the right candle stick.
#     Source: https://animasmarketing.com/candlesticks-different-types/
#     '''
#     if x.open < x.close and \
#        x.open_1 > x.close_1 and \
#        x.close_1 >= x.open and x.open_1 <= x.close and \
#        x.high_1 <= x.high and x.low_1 >= x.low:
#         return True
#     else:
#         return False
    
# def cs_engulfing_bearish(x):
#     '''
#     The body of the left candle stick must fit inside
#     the body of the right candle stick.
#     Source: https://animasmarketing.com/candlesticks-different-types/
#     '''
#     if x.open > x.close and \
#        x.open_1 < x.close_1 and \
#        x.close_1 <= x.open and x.open_1 >= x.close and \
#        x.high_1 <= x.high and x.low_1 >= x.low:
#         return True
#     else:
#         return False

# %%
# def add_features(df, skip_lookback=False, debug=False):
#     df2 = df.copy()
    
#     # this adds the past 3 records of price of data to each row
#     #if not skip_lookback:
#     #    df2 = add_lookback_trades(df2, 3)
    
#     print('  Features: calculating moving averages') if debug else None
#     df2['ma14'] = calculate_ma(df2)
#     df2['ma30'] = calculate_ma(df2,30)
#     df2['ma90'] = calculate_ma(df2,90)
    
#     print('  Features: calculating ATR and RSI') if debug else None
#     df2['atr'] = calculate_atr(df2)
#     df2['atr_diff'] = df2.atr.diff().fillna(0)
#     df2['atr_ma14'] = calculate_ma(df2, field='atr')
#     df2['rsi'] = calculate_rsi(df2)
#     df2['rsi_diff'] = df2.rsi.diff().fillna(0)
#     df2['rsi_ma14'] = calculate_ma(df2, field='rsi')
    
#     # Add levels of support and resistence
#     print('  Features: calculating levels of support and resistence') if debug else None
#     df2 = calculate_support_and_resistence_levels(df2)
    
#     # The below are booleans
#     print('  Features: calculating trends') if debug else None
#     df2['trend_up'] = calculate_upward_trend(df2,1)
#     df2['trend_up3'] = calculate_upward_trend(df2,3)
#     df2['trend_up14'] = calculate_upward_trend(df2,14)
#     df2['trend_up30'] = calculate_upward_trend(df2,30)

#     print('  Features: Identifying candlesticks') if debug else None
#     df2['cs_ss'] = df2.apply(cs_shooting_star, axis=1)
#     df2['cs_ssR'] = df2.apply(cs_shooting_star_R, axis=1)
#     df2['cs_hm'] = df2.apply(cs_hammer, axis=1)
#     df2['cs_hmR'] = df2.apply(cs_hammer_R, axis=1)

#     df2['cs_brh'] = df2.apply(cs_bearish_harami, axis=1)
#     df2['cs_buh'] = df2.apply(cs_bullish_harami, axis=1)
#     df2['cs_ebu'] = df2.apply(cs_engulfing_bullish, axis=1)
#     df2['cs_ebr'] = df2.apply(cs_engulfing_bearish, axis=1)
    
#     # This adds the past record's candlesticks to each row
#     print('  Features: Finalizing') if debug else None
#     #candlestick_cols = ['cs_ss','cs_ssR','cs_hm','cs_hmR','cs_brh','cs_buh','cs_ebu','cs_ebr']
#     #df2 = add_lookback_trades(df2, levels=1, cols=candlestick_cols)
    
#     # Other ideas:
#     # - Evening star
#     # - wedge shapes
#     # - double top / double bottom
    
#     return df2

# %% [markdown]
# ## Build X/y Data

# %%
# def keep_only_first(y, keep=2):
#     '''
#     Keep only the first X "True" values in a sequence.
#     For example: T,F,F,T,T,T,F,T,F  and keep=2
#                  T,F,F,T,T,F,F,T,F
#                            *
#     '''
#     boolean_out=False
#     if y.dtype == bool:
#         boolean_out=True
#     new_y = y.copy().astype(int)
    
#     prev_ones=0
#     for r in new_y.iteritems():
#         if r[1]==0 and prev_ones>0:
#             prev_ones=0
#         elif r[1]==1 and prev_ones<keep:
#             prev_ones+=1
#         elif r[1]==1:
#             new_y.at[r[0]]=0
    
#     if boolean_out:
#         new_y=new_y.astype(bool)
    
#     return new_y

# def to_buy(x, reverse=False):
#     '''
#     If first candle to pass high/low column is the target,
#     mark te row "True" for buying
#     '''
#     high_col = x.pass_high_col
#     high_col_num = int(high_col[high_col.find('_')+1:])
#     low_col = x.pass_low_col
#     low_col_num = int(low_col[low_col.find('_')+1:])
    
#     if not reverse:
#         if high_col_num < low_col_num and high_col_num > 1:
#             return True
#         elif low_col_num == 1:
#             if not x[low_col] and x[high_col]:
#                 return True
#             else:
#                 return False
#         else:
#             return False
#     else:
#         if low_col_num < high_col_num and low_col_num > 1:
#             return True
#         elif high_col_num == 1:
#             if not x[high_col] and x[low_col]:
#                 return True
#             else:
#                 return False
#         else:
#             return False
            
# def build_Xy(df, window=14, threshold_ratio=(0.04,0.02), use_atr=True,
#              atr_ratio=(2,1), reverse=False, debug=False):
#     '''
#     Build the X,y datasets
    
#     Parameters
#     ----------
#     window : int
#         number of records to look into the future to determine if this was a buy
    
#     threshold_ratio : tuple(float,float)
#         The high/low percentage to calculate target/stop-loss. Ignore if use_atr is True.
    
#     use_atr : boolean
#         Use the ATR to calculate stop-loss
    
#     atr_ratio : tuple(int,int)
#         The high/low multiplier for ATR to calculate target/stop-loss. Only used when
#         use_atr is True.
    
#     reverse : boolean
#         buying the other currency thus reverse logic
    
#     debug : boolean
#         show messages
    
#     '''
#     if use_atr==False and (not type(threshold_ratio) == tuple or len(threshold_ratio) != 2):
#         raise Exception("Parameter 'threshold_ratio' must be a tuple of size 2")
#     if use_atr==True and (not type(atr_ratio) == tuple or len(atr_ratio) != 2):
#         raise Exception("Parameter 'atr_ratio' must be a tuple of size 2")
    
#     df2 = df.copy()
    
#     print(' Build: Adding look-forward trades') if debug else None
#     df2 = add_lookforward_trades(df2, levels=window, cols=['high','low'])
    
#     high_cols = [f'high_{i}' for i in range(1,window+1)]
#     low_cols = [f'low_{i}' for i in range(1,window+1)]
    
#     # Calculate target and stop-loss
#     print(' Build: Calculating target and stop-loss') if debug else None
#     if not reverse:
#         if use_atr:
#             df2['atr'] = calculate_atr(df2)
#             df2['low_pip'] = (df2.close-df2.low)/df2.close
#             df2['stop_loss'] = df2.close-df2.close*(df2.atr*atr_ratio[1] + df2.low_pip)
#             df2['target'] = df2.close+df2.close*(df2.atr*atr_ratio[0])
#         else:
#             df2['stop_loss'] = df2.close-df2.close*threshold_ratio[1]
#             df2['target'] = df2.close+df2.close*threshold_ratio[0]
#     else:  # reverse
#         if use_atr:
#             df2['atr'] = calculate_atr(df2)
#             df2['high_pip'] = (df2.high-df2.close)/df2.close
#             df2['stop_loss'] = df2.close+df2.close*(df2.atr*atr_ratio[1] + df2.high_pip)
#             df2['target'] = df2.close-df2.close*(df2.atr*atr_ratio[0])
#         else:
#             df2['stop_loss'] = df2.close+df2.close*threshold_ratio[1]
#             df2['target'] = df2.close-df2.close*threshold_ratio[0]
            
#     # Determine if price crossed the target and/or stop-loss
#     print(' Build: Determining break points') if debug else None
#     for h,l in zip(high_cols, low_cols):
#         if not reverse:
#             df2[h] = df2[h]>=df2.target
#             df2[l] = df2[l]<=df2.stop_loss
#         else:  # reverse
#             df2[l] = df2[l]<=df2.target
#             df2[h] = df2[h]>=df2.stop_loss
    
#     # Identify the first column that pass the target/stop-loss
#     # WARNING: this is assuming idxmax() will continue to
#     # return the FIRST column with a True value.
#     print(' Build: Identifying target/stop-loss columns') if debug else None
#     df2['pass_high_col'] = df2[high_cols].idxmax(axis=1)
#     df2['pass_low_col'] = df2[low_cols].idxmax(axis=1)
    
#     print(' Build: Determining buy records') if debug else None
#     df2['buy'] = df2.apply(to_buy,reverse=reverse,axis=1)
    
#     # Build X
#     print(' Build: Adding features') if debug else None
#     X = add_features(df, debug=debug)
    
#     print(' Build: Finalizing') if debug else None
#     columns_to_drop = ['pair_id','close_time','created_at','updated_at']
#     X.drop(columns=columns_to_drop, inplace=True)
    
#     print(' Build: Trimming buy sequence to 2')
#     df2.buy = keep_only_first(df2.buy, keep=2)
    
#     return X, df2.buy, df2

# window=14
# %time X, y, raw = build_Xy(df, window=window, use_atr=True, atr_ratio=(20,5), reverse=False, debug=True)

# %%
# Parameters
#suffix='20210806l'
use_atr=True
ratio=(2, 1)
reverse=False
window=15

# %%
df_full = pd.read_pickle('data/candlestick_15m_ETHBTC_2107291134.pkl')  # This contains all the feature columns
df_full.set_index('open_time', inplace=True)
df_full.sort_index(inplace=True)
df_full.tail()

df_col_full = list(df_full.columns)
df_col_diff = df_col_full.copy()
for c in ['open','high','low','close']:
    df_col_diff.remove(c)
df_col_diff

df = df_full[['open','high','low','close']].copy()

def add_lookback_trades(df, levels=1, cols=['open','high','low','close']):
    '''
    Adds [cols] columns for previous records to each row. New columns are
    suffixed with the record backstep. For example: open_1 means the open
    price 1 record back.
    '''
    new_df = df.copy()
    for l in range(1,levels+1):
        new_cols={c:f'{c}_{l}' for c in cols}
        new_df = new_df.merge(df[cols].shift(l).bfill().rename(columns=new_cols),
                              how='left', left_index=True, right_index=True)
    return new_df

def add_lookforward_trades(df, levels=1, cols=['open','high','low','close']):
    '''
    Adds [cols] columns for future records to each row. New columns are
    suffixed with the record forwardstep. For example: open_1 means the open
    price 1 record forward.
    '''
    new_df = df.copy()
    for l in range(1,levels+1):
        new_cols={c:f'{c}_{l}' for c in cols}
        new_df = new_df.merge(df[cols].shift(-l).ffill().rename(columns=new_cols),
                              how='left', left_index=True, right_index=True)
    return new_df

def calculate_atr(df, period=14):
    '''
    Calculate the Average True Range (ATR)
    '''
    df2=df[['high','low','close']].copy()
    df2=add_lookback_trades(df2,1,['high','low','close'])
    df2['tr_calc'] = np.max([df2.high, df2.close_1], axis=0) - np.min([df2.low, df2.close_1], axis=0)
    return df2.tr_calc.rolling(period, min_periods=1).mean()

def keep_only_first(y, keep=2):
    '''
    Keep only the first X "True" values in a sequence.
    For example: T,F,F,T,T,T,F,T,F  and keep=2
                 T,F,F,T,T,F,F,T,F
                           *
    '''
    boolean_out=False
    if y.dtype == bool:
        boolean_out=True
    new_y = y.copy().astype(int)
    
    prev_ones=0
    for r in new_y.iteritems():
        if r[1]==0 and prev_ones>0:
            prev_ones=0
        elif r[1]==1 and prev_ones<keep:
            prev_ones+=1
        elif r[1]==1:
            new_y.at[r[0]]=0
    
    if boolean_out:
        new_y=new_y.astype(bool)
    
    return new_y

def to_buy(x, reverse=False):
    '''
    If first candle to pass high/low column is the target,
    mark te row "True" for buying
    '''
    high_col = x.pass_high_col
    high_col_num = int(high_col[high_col.find('_')+1:])
    low_col = x.pass_low_col
    low_col_num = int(low_col[low_col.find('_')+1:])
    
    if not reverse:
        if high_col_num < low_col_num and high_col_num > 1:
            return True
        elif low_col_num == 1:
            if not x[low_col] and x[high_col]:
                return True
            else:
                return False
        else:
            return False
    else:
        if low_col_num < high_col_num and low_col_num > 1:
            return True
        elif high_col_num == 1:
            if not x[high_col] and x[low_col]:
                return True
            else:
                return False
        else:
            return False
            
def build_Xy(df, df_full, window=14, threshold_ratio=(0.04,0.02), use_atr=True,
             atr_ratio=(2,1), reverse=False, debug=False):
    '''
    Build the X,y datasets
    
    Parameters
    ----------
    window : int
        number of records to look into the future to determine if this was a buy
    
    threshold_ratio : tuple(float,float)
        The high/low percentage to calculate target/stop-loss. Ignore if use_atr is True.
    
    use_atr : boolean
        Use the ATR to calculate stop-loss
    
    atr_ratio : tuple(int,int)
        The high/low multiplier for ATR to calculate target/stop-loss. Only used when
        use_atr is True.
    
    reverse : boolean
        buying the other currency thus reverse logic
    
    debug : boolean
        show messages
    
    '''
    if use_atr==False and (not type(threshold_ratio) == tuple or len(threshold_ratio) != 2):
        raise Exception("Parameter 'threshold_ratio' must be a tuple of size 2")
    if use_atr==True and (not type(atr_ratio) == tuple or len(atr_ratio) != 2):
        raise Exception("Parameter 'atr_ratio' must be a tuple of size 2")
    
    df2 = df.copy()
    
    print(' Build: Adding look-forward trades') if debug else None
    df2 = add_lookforward_trades(df2, levels=window, cols=['high','low'])
    
    high_cols = [f'high_{i}' for i in range(1,window+1)]
    low_cols = [f'low_{i}' for i in range(1,window+1)]
    
    # Calculate target and stop-loss
    print(' Build: Calculating target and stop-loss') if debug else None
    if not reverse:
        if use_atr:
            df2['atr'] = calculate_atr(df2)
            df2['stop_loss'] = df2.low-(df2.atr*atr_ratio[1])
            df2['target'] = df2.close+(df2.atr*atr_ratio[0])
        else:
            df2['stop_loss'] = df2.close-df2.close*threshold_ratio[1]
            df2['target'] = df2.close+df2.close*threshold_ratio[0]
    else:  # reverse
        if use_atr:
            df2['atr'] = calculate_atr(df2)
            df2['stop_loss'] = df2.high+(df2.atr*atr_ratio[1])
            df2['target'] = df2.close-(df2.atr*atr_ratio[0])
        else:
            df2['stop_loss'] = df2.close+df2.close*threshold_ratio[1]
            df2['target'] = df2.close-df2.close*threshold_ratio[0]
            
    # Determine if price crossed the target and/or stop-loss
    print(' Build: Determining break points') if debug else None
    for h,l in zip(high_cols, low_cols):
        if not reverse:
            df2[h] = df2[h]>=df2.target
            df2[l] = df2[l]<=df2.stop_loss
        else:  # reverse
            df2[l] = df2[l]<=df2.target
            df2[h] = df2[h]>=df2.stop_loss
    
    # Identify the first column that pass the target/stop-loss
    # WARNING: this is assuming idxmax() will continue to
    # return the FIRST column with a True value.
    print(' Build: Identifying target/stop-loss columns') if debug else None
    df2['pass_high_col'] = df2[high_cols].idxmax(axis=1)
    df2['pass_low_col'] = df2[low_cols].idxmax(axis=1)
    
    print(' Build: Determining buy records') if debug else None
    df2['buy'] = df2.apply(to_buy,reverse=reverse,axis=1)
    
    # Build X/y
    X = df.merge(df_full, how='left', left_index=True, right_index=True)
    y = df2[['buy']].astype(int)
    
    print(' Build: Dropping Unnecessary columns') if debug else None
    columns_to_drop = ['pair_id','close_time']
    X.drop(columns=columns_to_drop, inplace=True)
    
    print (' Build: Dropping NaN rows') if debug else None
    not_nan_rows = X.notnull().all(axis=1)
    X = X[not_nan_rows]
    y = y[not_nan_rows]
    
    print(' Build: Converting booleans to ints') if debug else None
    for col in X.columns:
        if X[col].dtype.kind in ['b','O']:
            X[col] = X[col].astype(int)
    
    #print(' Build: Trimming buy sequence to 2')
    #y.buy = keep_only_first(y.buy, keep=2)
    
    return X, y, df2

# %time X, y, raw = build_Xy(df, df_full[df_col_diff], window=window, use_atr=use_atr, atr_ratio=ratio, threshold_ratio=ratio, reverse=reverse, debug=True)
# Out:
#  Build: Adding look-forward trades
#  Build: Calculating target and stop-loss
#  Build: Determining break points
#  Build: Identifying target/stop-loss columns
#  Build: Determining buy records
#  Build: Dropping Unnecessary columns
#  Build: Dropping NaN rows
#  Build: Converting booleans to ints
# Wall time: 12.8 s

# %%
# The average ratio of buys/not-buys across whole period
y.sum() / len(y)
# Out:
# buy    0.290238
# dtype: float64

# %%
# Plot the ratio of buys/not-buys for each month
months = [m for m in y.groupby(pd.Grouper(freq='M')).count().index]
ms = [m.strftime('%Y-%m') for m in months]
ratio_buys = [y.loc[m].sum() / len(y.loc[m]) for m in ms]
plt.plot(months, ratio_buys)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# This should the buy/not-buy ratio in the `y` label data for each month based on the `build_Xy` params.

# %%
def plot_purchase(raw_df, buy_date, window, reverse=False):
    
    def build_subplot(df, idxs=[], prices=[]):
        df = df.reset_index()
        signals = pd.Series(np.NaN, index=df.index)
        for i,p in zip(idxs,prices):
            signals.at[i]=p
        return signals
    
    def find_sell_point(df, index, reverse=False):
        x = df.loc[index].copy()
        high_col = x.pass_high_col
        high_col_num = int(high_col[high_col.find('_')+1:])
        low_col = x.pass_low_col
        low_col_num = int(low_col[low_col.find('_')+1:])

        if not reverse:
            if high_col_num < low_col_num and high_col_num > 1:
                return (high_col_num,x.target,'g')
            elif low_col_num == 1:
                if not x[low_col] and x[high_col]:
                    return (high_col_num,x.target,'g')
                else:
                    return (low_col_num,x.stop_loss,'r')
            else:
                return (low_col_num,x.stop_loss,'r')
        else:
            if low_col_num < high_col_num and low_col_num > 1:
                return (low_col_num,x.target,'g')
            elif high_col_num == 1:
                if not x[high_col] and x[low_col]:
                    return (low_col_num,x.target,'g')
                else:
                    return (high_col_num,x.stop_loss,'r')
            else:
                return (high_col_num,x.stop_loss,'r')
    
    def find_first_buypoint(df):
        df = df.reset_index()
        signals = pd.Series(np.NaN, index=df.index)
        for r in df[(df.buy-df.buy.shift(1))==1].iterrows():
            signals[r[0]] = r[1].low*0.99
        return signals
        
        
    
    s=window//2
    e=(window*3)-s

    tmp = raw_df.copy()
    price, stop_loss, target = tmp.loc[buy_date][['close', 'stop_loss','target']].to_list()
    tmp = tmp.reset_index()

    b=tmp[tmp.open_time == buy_date].index[0]
    period_end=tmp.loc[b+window].open_time
    graph_df=tmp.loc[b-s:b+e].set_index('open_time')

    boxes = [[(buy_date, price), (period_end, price), (period_end, target), (buy_date, target), (buy_date, price)],
             [(buy_date, price), (period_end, price), (period_end, stop_loss), (buy_date, stop_loss), (buy_date, price)]
            ]
    
    buy_signal = build_subplot(graph_df, [s-1], [price])
    sell_pnt, sell_prc, sell_clr = find_sell_point(graph_df, buy_date, reverse)
    sell_signal = build_subplot(graph_df, [s+sell_pnt-1], [sell_prc])
    
    print('Buy Date:', buy_date, "Price:", price, 'Target:', target, "Stop loss", stop_loss)
    apds=[mpf.make_addplot(buy_signal, type='scatter', markersize=200, marker='>',color='b'),
          mpf.make_addplot(sell_signal, type='scatter', markersize=200, marker='>',color=sell_clr),
         ]

    fig, ax = mpf.plot(graph_df,
                       type='candlestick',
                       alines=dict(alines=boxes,colors=['g','r'],alpha=0.35),
                       #volume=True,
                       title=f"ETHBTC - 15 min\n{buy_date.strftime('%Y-%m-%d')}",
                       returnfig=True,
                       addplot=apds,
                      )
    
    # Add a box 
    from matplotlib.offsetbox import AnchoredText
    pl = round(abs(price-sell_prc)/price*100,2)
    pl = f"Profit {pl}%" if sell_clr=='g' else f"Loss {pl}%"
    at = AnchoredText(pl,
                      prop=dict(size=15,), frameon=True,
                      loc='upper left'
                      )
    at.patch.set_boxstyle("round,pad=0.,rounding_size=0.2")
    ax[0].add_artist(at)
    
    return fig,ax

# %%
# Parameters
use_atr=False
ratio=(0.01, 0.005)
reverse=False
window=15

# %time X, y, raw = build_Xy(df, df_full[df_col_diff], window=window, use_atr=use_atr, atr_ratio=ratio, threshold_ratio=ratio, reverse=reverse, debug=True)

index = y[y.buy==1].index[-50]
fig,ax = plot_purchase(raw, index, window=15, reverse=reverse)
plt.show()
# Out:
#  Build: Adding look-forward trades
#  Build: Calculating target and stop-loss
#  Build: Determining break points
#  Build: Identifying target/stop-loss columns
#  Build: Determining buy records
#  Build: Dropping Unnecessary columns
#  Build: Dropping NaN rows
#  Build: Converting booleans to ints
# Wall time: 12.4 s
# Buy Date: 2021-07-26 04:00:00 Price: 0.060497 Target: 0.061101970000000005 Stop loss 0.060194515000000004

# %%
# Parameters
use_atr=True
ratio=(2, 1)
reverse=True
window=15

# %time X, y, raw = build_Xy(df, df_full[df_col_diff], window=window, use_atr=use_atr, atr_ratio=ratio, threshold_ratio=ratio, reverse=reverse, debug=True)

index = y[y.buy==1].index[-150]
fig,ax = plot_purchase(raw, index, window=15, reverse=reverse)
plt.show()
# Out:
#  Build: Adding look-forward trades
#  Build: Calculating target and stop-loss
#  Build: Determining break points
#  Build: Identifying target/stop-loss columns
#  Build: Determining buy records
#  Build: Dropping Unnecessary columns
#  Build: Dropping NaN rows
#  Build: Converting booleans to ints
# Wall time: 12.7 s
# Buy Date: 2021-07-25 01:30:00 Price: 0.063212 Target: 0.06283657142857144 Stop loss 0.0634827142857143

# %%
# Original Code

# def plot_purchase(raw_df, buy_date, window, reverse=False):
    
#     def build_subplot(df, idxs=[], prices=[]):
#         df = df.reset_index()
#         signals = pd.Series(np.NaN, index=df.index)
#         for i,p in zip(idxs,prices):
#             signals.at[i]=p
#         return signals
    
#     def find_sell_point(df, index, reverse=False):
#         x = df.loc[index].copy()
#         high_col = x.pass_high_col
#         high_col_num = int(high_col[high_col.find('_')+1:])
#         low_col = x.pass_low_col
#         low_col_num = int(low_col[low_col.find('_')+1:])

#         if not reverse:
#             if high_col_num < low_col_num and high_col_num > 1:
#                 return (high_col_num,x.target,'g')
#             elif low_col_num == 1:
#                 if not x[low_col] and x[high_col]:
#                     return (high_col_num,x.target,'g')
#                 else:
#                     return (low_col_num,x.stop_loss,'r')
#             else:
#                 return (low_col_num,x.stop_loss,'r')
#         else:
#             if low_col_num < high_col_num and low_col_num > 1:
#                 return (low_col_num,x.target,'g')
#             elif high_col_num == 1:
#                 if not x[high_col] and x[low_col]:
#                     return (low_col_num,x.target,'g')
#                 else:
#                     return (high_col_num,x.stop_loss,'r')
#             else:
#                 return (high_col_num,x.stop_loss,'r')
    
#     def find_first_buypoint(df):
#         df = df.reset_index()
#         signals = pd.Series(np.NaN, index=df.index)
#         for r in df[(df.buy-df.buy.shift(1))==1].iterrows():
#             signals[r[0]] = r[1].low*0.99
#         return signals
        
        
    
#     s=window//2
#     e=(window*3)-s

#     tmp = raw_df.copy()
#     price, stop_loss, target = tmp.loc[buy_date][['close', 'stop_loss','target']].to_list()
#     tmp = tmp.reset_index()

#     b=tmp[tmp.open_time == buy_date].index[0]
#     period_end=tmp.loc[b+window].open_time
#     graph_df=tmp.loc[b-s:b+e].set_index('open_time')

#     boxes = [[(buy_date, price), (period_end, price), (period_end, target), (buy_date, target), (buy_date, price)],
#              [(buy_date, price), (period_end, price), (period_end, stop_loss), (buy_date, stop_loss), (buy_date, price)]
#             ]
    
#     buy_signal = build_subplot(graph_df, [s-1], [price])
#     sell_pnt, sell_prc, sell_clr = find_sell_point(graph_df, buy_date, reverse)
#     sell_signal = build_subplot(graph_df, [s+sell_pnt-1], [sell_prc])
    
    
#     apds=[mpf.make_addplot(buy_signal, type='scatter', markersize=200, marker='>',color='b'),
#           mpf.make_addplot(sell_signal, type='scatter', markersize=200, marker='>',color=sell_clr),
#          ]

#     fig, ax = mpf.plot(graph_df,
#                        type='candlestick',
#                        alines=dict(alines=boxes,colors=['g','r'],alpha=0.35),
#                        volume=True, title=f"ETHBTC - 15 min\n{buy_date.strftime('%Y-%m-%d')}",
#                        returnfig=True,
#                        addplot=apds,
#                       )
    
#     # Add a box 
#     from matplotlib.offsetbox import AnchoredText
#     pl = round(abs(price-sell_prc)/price*100,2)
#     pl = f"Profit {pl}%" if sell_clr=='g' else f"Loss {pl}%"
#     at = AnchoredText(pl,
#                       prop=dict(size=15,), frameon=True,
#                       loc='upper left'
#                       )
#     at.patch.set_boxstyle("round,pad=0.,rounding_size=0.2")
#     ax[0].add_artist(at)
    
#     return fig,ax

# # removed because needed to add added high_1...low_1 and pass_high_col, pass_low_col
# # to suport the arrows
# #graph_cols=['open','close','high','low','volume','stop_loss','target','buy']  

# index = y[y==True].index[50]
# fig,ax = plot_purchase(raw, index, window=14)

# # Tests on how to annotate the images

# # ax[0].annotate('test',
# #                xy=(index,0.08), xycoords='data',
# #                xytext=(index,0.08), textcoords='data',
               
# #               )

# # ax[0].annotate('testing', xy=(1, 1),  xycoords='axes fraction',
# #             xytext=(0.08, 0.095), textcoords='axes fraction',
# #             arrowprops=dict(facecolor='black', shrink=0.05),
# #             horizontalalignment='right', verticalalignment='top',
# #             )

# # ax[2].text(
# #     0, 0, "Direction", ha="center", va="center", rotation=45, size=15,
# #     bbox=dict(boxstyle="rarrow,pad=0.3", fc="cyan", ec="b", lw=2))

# plt.show()

# %% [markdown]
# This displays the buying point, monitoring window and the sell point.  This example is constructed on the labeled data so any index given in the above `index` variable would always result in a profit (candle breaking the target price) before the stop-loss.

# %%
def plot_buypoints(raw_df, buy_date, window):
    
    def build_subplot(df, idxs=[], prices=[]):
        df = df.reset_index()
        signals = pd.Series(np.NaN, index=df.index)
        for i,p in zip(idxs,prices):
            signals.at[i]=p
        return signals
    
    def find_first_buypoint(df):
        df = df.reset_index()
        signals = pd.Series(np.NaN, index=df.index)
        for r in df[(df.buy-df.buy.shift(1))==1].iterrows():
            signals[r[0]] = r[1].low*0.99
        return signals
    
    s=window//2
    e=(window*3)-s

    tmp = raw_df.copy().reset_index()
    b=tmp[tmp.open_time == buy_date].index[0]
    graph_df=tmp.loc[b-s:b+e].set_index('open_time')
    
    # Show all other buy points
    buypoints = build_subplot(graph_df, list(graph_df.reset_index()[graph_df.reset_index().buy == True].index),
                              graph_df.reset_index()[graph_df.reset_index().buy == True].low*0.99
                             )
    
    # Show only first buy point in series
    first_buypoints = find_first_buypoint(graph_df)
    
    
    apds=[mpf.make_addplot(buypoints, type='scatter', markersize=200, marker='^',),
          mpf.make_addplot(first_buypoints, type='scatter', markersize=200, marker='^',color='r'),
         ]

    fig, ax = mpf.plot(graph_df,
                       type='candlestick',
                       volume=True, title=f"ETHBTC - 15 min\n{buy_date.strftime('%Y-%m-%d')}",
                       returnfig=True,
                       addplot=apds,
                      )
    
    return fig,ax
 

index = y[y==True].index[50]
fig,ax = plot_buypoints(raw, index, window=14)

plt.show()

# %% [markdown]
# Here's a graph I made to see what my "labeler" is doing.  (the labeler is automatically determining if a candle should be considered a "buy" or "not buy").  The labeler is looking 14 candles in the future and within that window, if the first candle that breaks my window is on the target price, then I mark that candle a "buy".  The blue and red arrows all indicate a "buy".  The red arrows are the first "buy" in a sequence of buys.  I'm thinking of changing my script to reject all but the first in the sequence.

# %%
# Convert all booleans to ints
for col in X.columns:
    if X[col].dtype == bool:
        X[col] = X[col].astype(int)
y = y.astype(int)

# %% [markdown]
# #  Load Pickles

# %%
import pandas as pd

pd.set_option('display.max_columns', 500)

def load_split_data(suffix=None, split=False, window=14):
    if suffix==None:
        suffix='DEFAULT'
    try:
        X = pd.read_pickle(f'data/X_{suffix}.pkl')
        y = pd.read_pickle(f'data/y_{suffix}.pkl')
    except:
        X, y, _ = build_Xy(df, window=window, use_atr=True, atr_ratio=(20,5), reverse=False, debug=True)
        X.to_pickle(f'data/X_{suffix}.pkl')
        y.to_pickle(f'data/y_{suffix}.pkl')
        
    if split:
        X_train, y_train, X_test, y_test = train_test_split(X, y, X.loc[:'2019'].index, X.loc['2020':].index)
        return X_train, y_train, X_test, y_test
    else:
        return X, y
    
X, y = load_split_data(suffix='20210715')

# %% [markdown]
# # Check Various Classifiers

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import f1_score, precision_score, recall_score
from sklearn.naive_bayes import GaussianNB
import xgboost as xgb

def print_scores(clf,X,y):
    print(f"2017 acc = {clf.score(X.loc['2017'], y.loc['2017'])} - " + \
          f"f1 = {f1_score(y.loc['2017'],clf.predict(X.loc['2017']))} - " + \
          f"prec = {precision_score(y.loc['2017'],clf.predict(X.loc['2017']), zero_division=0)} - " + \
          f"recl = {recall_score(y.loc['2017'],clf.predict(X.loc['2017']), zero_division=0)}"
         )
    print(f"2018 acc = {clf.score(X.loc['2018'], y.loc['2018'])} - " + \
          f"f1 = {f1_score(y.loc['2018'],clf.predict(X.loc['2018']))} - " + \
          f"prec = {precision_score(y.loc['2018'],clf.predict(X.loc['2018']), zero_division=0)} - " + \
          f"recl = {recall_score(y.loc['2017'],clf.predict(X.loc['2017']), zero_division=0)}"
         )
    print(f"2019 acc = {clf.score(X.loc['2019'], y.loc['2019'])} - " + \
          f"f1 = {f1_score(y.loc['2019'],clf.predict(X.loc['2019']))} - " + \
          f"prec = {precision_score(y.loc['2019'],clf.predict(X.loc['2019']), zero_division=0)} - " + \
          f"recl = {recall_score(y.loc['2017'],clf.predict(X.loc['2017']), zero_division=0)}"
         )
    print(f"2020 acc = {clf.score(X.loc['2020'], y.loc['2020'])} - " + \
          f"f1 = {f1_score(y.loc['2020'],clf.predict(X.loc['2020']))} - " + \
          f"prec = {precision_score(y.loc['2020'],clf.predict(X.loc['2020']), zero_division=0)} - " + \
          f"recl = {recall_score(y.loc['2017'],clf.predict(X.loc['2017']), zero_division=0)}"
         )
    print(f"2021 acc = {clf.score(X.loc['2021'], y.loc['2021'])} - " + \
          f"f1 = {f1_score(y.loc['2021'],clf.predict(X.loc['2021']))} - " + \
          f"prec = {precision_score(y.loc['2021'],clf.predict(X.loc['2021']), zero_division=0)} - " + \
          f"recl = {recall_score(y.loc['2021'],clf.predict(X.loc['2021']), zero_division=0)}"
         )


clfs = {'Logistic Regression': LogisticRegression(random_state=0, max_iter=10000),
        'Random Forest': RandomForestClassifier(random_state=0),
        'Gradient Boost': GradientBoostingClassifier(random_state=0, learning_rate=0.1),
        'Naive Bayes': GaussianNB(),
        'XGBoost' : xgb.XGBClassifier(n_jobs=-1, random_state=42, use_label_encoder=False),
       }

# %%
for k,clf in clfs.items():
    print(f'{k}:')
    # %time clf.fit(X.loc['2018':'2020'], y.loc['2018':'2020'])
    print_scores(clf,X,y)
    print(' ')
# Out:
# Logistic Regression:
# 2017 acc = 0.8506231671554252 - f1 = 0.012121212121212123 - prec = 0.6521739130434783 - recl = 0.006117455138662317
# 2018 acc = 0.8413509865303427 - f1 = 0.017081850533807827 - prec = 0.5217391304347826 - recl = 0.006117455138662317
# 2019 acc = 0.8123299831056897 - f1 = 0.03447259870359458 - prec = 0.5416666666666666 - recl = 0.006117455138662317
# 2020 acc = 0.8076396416956695 - f1 = 0.04988023108355644 - prec = 0.5145348837209303 - recl = 0.006117455138662317
# 2021 acc = 0.8172492836676217 - f1 = 0.02207911683532659 - prec = 0.5454545454545454 - recl = 0.011267605633802818
# Wall time: 198 ms
#
# Random Forest:
# 2017 acc = 0.8464687194525904 - f1 = 0.022559315441462464 - prec = 0.24369747899159663 - recl = 0.011827079934747145
# 2018 acc = 0.9999712800482495 - f1 = 0.9999095431931254 - prec = 1.0 - recl = 0.011827079934747145
# 2019 acc = 0.9999713655756951 - f1 = 0.9999239138705014 - prec = 1.0 - recl = 0.011827079934747145
# 2020 acc = 1.0 - f1 = 1.0 - prec = 1.0 - recl = 0.011827079934747145
# 2021 acc = 0.8149570200573066 - f1 = 0.07610872675250357 - prec = 0.44333333333333336 - recl = 0.04162754303599374
# Wall time: 8.08 s
#
# Gradient Boost:
# 2017 acc = 0.8500733137829912 - f1 = 0.009685230024213074 - prec = 0.46153846153846156 - recl = 0.004893964110929853
# 2018 acc = 0.8420689853241047 - f1 = 0.028273546562996993 - prec = 0.6106870229007634 - recl = 0.004893964110929853
# 2019 acc = 0.8144489305042523 - f1 = 0.0553935860058309 - prec = 0.6597222222222222 - recl = 0.004893964110929853
# 2020 acc = 0.8100644719575512 - f1 = 0.06409895979758223 - prec = 0.631578947368421 - recl = 0.004893964110929853
# 2021 acc = 0.8174212034383954 - f1 = 0.05291319857312723 - prec = 0.5266272189349113 - recl = 0.02785602503912363
# Wall time: 719 ms
#
# Naive Bayes:
# 2017 acc = 0.7651515151515151 - f1 = 0.22374798061389334 - prec = 0.2216 - recl = 0.22593800978792822
# 2018 acc = 0.7337947672247911 - f1 = 0.2773836438761986 - prec = 0.24373201808466913 - recl = 0.22593800978792822
# 2019 acc = 0.7229333104257939 - f1 = 0.303082685105157 - prec = 0.28774617067833697 - recl = 0.22593800978792822
# 2020 acc = 0.7000342328978147 - f1 = 0.3202534100458983 - prec = 0.28418999541073886 - recl = 0.22593800978792822
# 2021 acc = 0.6636676217765043 - f1 = 0.3274894007104389 - prec = 0.25831525668835864 - recl = 0.4472613458528952
# Wall time: 557 ms
#
# XGBoost:
# [17:55:33] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# 2017 acc = 0.8421309872922776 - f1 = 0.07780157030692363 - prec = 0.31142857142857144 - recl = 0.04445350734094616
# 2018 acc = 0.8607082340101668 - f1 = 0.24384159650763954 - prec = 0.8826185101580135 - recl = 0.04445350734094616
# 2019 acc = 0.8320304670274604 - f1 = 0.2385773624091381 - prec = 0.8118374558303887 - recl = 0.04445350734094616
# 2020 acc = 0.8276944143321732 - f1 = 0.23852748361069087 - prec = 0.8023748939779474 - recl = 0.04445350734094616
# 2021 acc = 0.8130085959885387 - f1 = 0.13287270794578795 - prec = 0.44014084507042256 - recl = 0.0782472613458529
# Wall time: 391 ms
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\caps\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
# from sklearn.metrics import roc_auc_score
# from sklearn.metrics import roc_curve, auc

from sklearn.metrics import plot_det_curve
from sklearn.metrics import plot_roc_curve

def display_roc_curve(classifiers, X_test, y_test):
#     # Source: https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html#sphx-glr-auto-examples-model-selection-plot-roc-py
#     y_score = clf.decision_function(X_test)
#     n_classes=2
    
#     # Compute ROC curve and ROC area for each class
#     fpr, tpr, _ = roc_curve(y_test, y_score)
#     roc_auc = auc(fpr, tpr)
    
#     # Plot
#     plt.figure()
#     lw = 2
#     plt.plot(fpr, tpr, color='darkorange',
#              lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
#     plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
#     plt.xlim([0.0, 1.0])
#     plt.ylim([0.0, 1.05])
#     plt.xlabel('False Positive Rate')
#     plt.ylabel('True Positive Rate')
#     plt.title(f'{name} - ROC Curve')
#     plt.legend(loc="lower right")
#     plt.show()

    # Source: https://scikit-learn.org/stable/auto_examples/model_selection/plot_det.html#sphx-glr-auto-examples-model-selection-plot-det-py
    fig, [ax_roc, ax_det] = plt.subplots(1, 2, figsize=(11, 5))
    for name, clf in classifiers.items():
        plot_roc_curve(clf, X_test, y_test, ax=ax_roc, name=name)
        plot_det_curve(clf, X_test, y_test, ax=ax_det, name=name)
    ax_roc.set_title('Receiver Operating Characteristic (ROC) curves')
    ax_det.set_title('Detection Error Tradeoff (DET) curves')
    ax_roc.grid(linestyle='--')
    ax_det.grid(linestyle='--')
    plt.show()
    

display_roc_curve(clfs, X.loc['2018'], y.loc['2018'])

# %%
# Where are we identifying "buys" in the model?
tmp = np.where(clf.predict(X)==1)
tmp[0][-50:]

# %%
def plot_predictions(X, y, clf, start_date, num_candles=50):
    
    def build_confusion_matrix_lists(X, y, y_pred):
        #y = y.reset_index()
        tp = pd.Series(np.NaN, index=y.index)
        fn = pd.Series(np.NaN, index=y.index)
        fp = pd.Series(np.NaN, index=y.index)
        tn = pd.Series(np.NaN, index=y.index)
        for i,ye in enumerate(y.iteritems()):
            #print(f'Values: {ye[1]} and {y_pred[i]}')
            #break
            if ye[1]==y_pred[i] and ye[1]==1:
                tp.at[ye[0]]=X.loc[ye[0]].low * 0.99
            elif y_pred[i]==1:
                fp.at[ye[0]]=X.loc[ye[0]].low * 0.99
            elif ye[1]==1:
                fn.at[ye[0]]=X.loc[ye[0]].low * 0.99
            else:
                tn.at[ye[0]]=X.loc[ye[0]].low * 0.99
        return tp,fn,fp,tn

    b=X.reset_index()[X.reset_index().open_time == start_date].index[0]
    Xs=X.iloc[b:b+num_candles]
    ys=y.iloc[b:b+num_candles]
    y_pred=clf.predict(Xs)
    
    tp,fn,fp,_ = build_confusion_matrix_lists(Xs,ys,y_pred)
    #tmp = pd.DataFrame(ys)
    #tmp['pred'] = y_pred
    #display(tmp)
    
    apds=[]
    if any(fn.notna()):
        apds.append(mpf.make_addplot(fn, type='scatter', markersize=200, marker='o',color='y'))
    if any(tp.notna()):
        apds.append(mpf.make_addplot(tp, type='scatter', markersize=200, marker='+',color='g'))
    if any(fp.notna()):
        apds.append(mpf.make_addplot(fp, type='scatter', markersize=200, marker='x',color='r'))

    fig, ax = mpf.plot(Xs,
                       type='candlestick',
                       volume=True, title=f"ETHBTC - 15 min\n{start_date.strftime('%Y-%m-%d')}",
                       returnfig=True,
                       addplot=apds,
                      )
    
    return fig,ax
 

#index = y[y==True].index[50]
index = y.index[134822]
fig,ax1 = plot_predictions(X, y, clfs['Gradient Boost'], index)

plt.show()

fig,ax2 = plot_purchase(raw, index, window=14)

# fig,ax = plt.subplots(1,2,figsize=(15,10))
# ax[0]=ax1
# ax[1]=ax2

# %% [markdown]
# This is a plot of True Positives, False Negatives, and False Positives.  No point plotting TNs.
# - True Positives - Green "+" - these are the good guesses that we want
# - False Positives - Red "x" - these are "buys" when we shouldn't be buying VERY BAD
# - False Negatives - Yellow "o" - these are "not buys" when we should buy.  Not as bad as FP.

# %% [markdown]
# # Create Train/Test Split

# %%
def train_test_split(X, y, train_idx=None, test_idx=None):
    X_train = X.loc[train_idx]
    y_train = y.loc[train_idx]
    X_test = X.loc[test_idx]
    y_test = y.loc[test_idx]
    return (X_train, y_train, X_test, y_test)

X_train, y_train, X_test, y_test = train_test_split(X, y, X.loc[:'2019'].index, X.loc['2020':].index)

# %% [markdown]
# # Save Pickles

# %%
# suffix='20210715'
# X.to_pickle(f'data/X_{suffix}.pkl')
# y.to_pickle(f'data/y_{suffix}.pkl')

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
import xgboost as xgb

from sklearn.metrics import f1_score, precision_score, recall_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score

def print_scores(clf,X,y):
    for yr in X.index.year.unique():
        year = str(yr)
        print(f"  {year} acc = {clf.score(X.loc[year], y.loc[year])} - " + \
              f"f1 = {f1_score(y.loc[year],clf.predict(X.loc[year]))} - " + \
              f"prec = {precision_score(y.loc[year],clf.predict(X.loc[year]), zero_division=0)} - " + \
              f"recl = {recall_score(y.loc[year],clf.predict(X.loc[year]), zero_division=0)}"
             )

clfs = {
        'Logistic Regression': LogisticRegression(random_state=0, max_iter=1000), # ~54% prec
        'Random Forest': RandomForestClassifier(random_state=0, max_depth=3), # 0% prec
        #'Gradient Boost': GradientBoostingClassifier(random_state=0, learning_rate=0.1), # ~32% prec
        #'LinearSVC': make_pipeline(StandardScaler(), LinearSVC(random_state=0, tol=1e-5)),  # ~48% prec
        #'SVC' : make_pipeline(StandardScaler(), SVC(gamma='auto', random_state=0)), # never came back ~20min
        #'AdaBoost': make_pipeline(StandardScaler(), AdaBoostClassifier(n_estimators=100, random_state=0)), # ~32%
        'XGBoost' : xgb.XGBClassifier(n_estimators=20, random_state=42, learning_rate=0.1, n_jobs=-1, gamma=0.9, max_depth=4)
       }


for k,clf in clfs.items():
    scores = cross_val_score(clf, X, y, scoring='precision', cv=5, n_jobs=-1)
    print("%s: precision: %0.2f (+/- %0.2f)" % (k, scores.mean(), scores.std()))

# %%
scores

# %%
from sklearn.metrics import plot_det_curve
from sklearn.metrics import plot_roc_curve

def display_roc_curve(classifiers, X_test, y_test, X_train=None, y_train=None):
    # Source: https://scikit-learn.org/stable/auto_examples/model_selection/plot_det.html#sphx-glr-auto-examples-model-selection-plot-det-py
    fig, [ax_roc, ax_det] = plt.subplots(1, 2, figsize=(11, 5))
    for name, clf in classifiers.items():
        if X_train is not None:
            print(f'Fitting {name}...', end=' ')
            clf.fit(X_train, y_train)
            print('prec: %0.2f' % (precision_score(y_test,clf.predict(X_test), zero_division=0)))
        plot_roc_curve(clf, X_test, y_test, ax=ax_roc, name=name)
        plot_det_curve(clf, X_test, y_test, ax=ax_det, name=name)
    ax_roc.set_title('Receiver Operating Characteristic (ROC) curves')
    ax_det.set_title('Detection Error Tradeoff (DET) curves')
    ax_roc.grid(linestyle='--')
    ax_det.grid(linestyle='--')
    plt.show()

display_roc_curve(clfs, X, y, X, y)

# %%
display_roc_curve(clfs, X.loc['2020':], y.loc['2020':], X.loc[:'2019'], y.loc[:'2019'])

# %% [markdown]
# # GradientBoost Grid Search

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'learning_rate': [0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1],
              'loss': ['deviance'],
              'n_estimators': [100],
              'criterion': ['friedman_mse'],
              'max_depth' : [3],
              'random_state': [0],
              'max_features' : [None]
             }

gbc = GradientBoostingClassifier()
clf = GridSearchCV(gbc, parameters, n_jobs=-1, verbose=4, scoring='precision').fit(X, y)

# %%
pd.DataFrame(clf.cv_results_)

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'learning_rate': [0.03, 0.06, 0.1],
              'loss': ['deviance', 'exponential'],
              'n_estimators': [100, 500, 1000],
              'criterion': ['friedman_mse', 'mse', 'mae'],
              'max_depth' : [3,4,5],
              'random_state': [0],
              'max_features' : [None, 'sqrt', 'log2']
             }

gbc = GradientBoostingClassifier()
clf = GridSearchCV(gbc, parameters, n_jobs=-1, verbose=4, scoring='precision').fit(X, y)

# %%
pd.DataFrame(clf.cv_results_).to_csv('grid_search_output.csv')

# %% [markdown]
# # XGBoost Grid Search

# %%
from sklearn.model_selection import GridSearchCV
import xgboost as xgb

# %%
parameters = {'learning_rate': [0.1],
              'n_estimators': [19],
              'gamma': [0.9],
              'max_depth' : [4],
              'booster' :['gblinear'],
             }

# %%
#xgb.XGBClassifier(n_estimators=20, random_state=42, learning_rate=0.1, n_jobs=-1, gamma=0.9, max_depth=4)
gbc = xgb.XGBClassifier(n_jobs=-1, random_state=42)
clf = GridSearchCV(gbc, parameters, verbose=4, scoring='precision').fit(X, y, eval_metric=['map'])
#pd.DataFrame(clf.cv_results_)#.to_csv('grid_search_output.csv')

# %%
pd.DataFrame(clf.cv_results_)
