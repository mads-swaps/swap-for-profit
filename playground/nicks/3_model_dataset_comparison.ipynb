# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Load Datasets

# %%
def train_test_split(X, y, train_idx=None, test_idx=None):
    X_train = X.loc[train_idx]
    y_train = y.loc[train_idx]
    X_test = X.loc[test_idx]
    y_test = y.loc[test_idx]
    return (X_train, y_train, X_test, y_test)

def load_split_data(suffix=None, split=False, window=14):
    if suffix==None:
        suffix='DEFAULT'
    try:
        X = pd.read_pickle(f'data/X_{suffix}.pkl')
        y = pd.read_pickle(f'data/y_{suffix}.pkl')
    except:
        X, y, _ = build_Xy(df, window=window, use_atr=True, atr_ratio=(20,5), reverse=False, debug=True)
        X.to_pickle(f'data/X_{suffix}.pkl')
        y.to_pickle(f'data/y_{suffix}.pkl')
        
    if split:
        X_train, y_train, X_test, y_test = train_test_split(X, y, X.loc['2018':'2020'].index, X.loc['2021':].index)
        return X_train, y_train, X_test, y_test
    else:
        return X, y
    
dataset_suffixes = [
    '20210806a',
    '20210806b',
    '20210806c',
    '20210806d',
    '20210806e',
    '20210806f',
    '20210806g',
    '20210806h',
    '20210806i',
    '20210806j',
    '20210806k',
    '20210806l',
]

datasets = {}

for d in dataset_suffixes:
    X_train, y_train, X_test, y_test = load_split_data(suffix=d, split=True)
    dataset_info = pd.read_pickle(f'data/data_file_hist_all_cols.pkl').loc[d]
    data = dict(X_train = X_train,
                y_train = y_train,
                X_test = X_test,
                y_test = y_test,
                use_atr = dataset_info['use_atr'],
                ratio = dataset_info['ratio'],
                reverse = dataset_info['reverse'],
                window = dataset_info['window'],
               )
    datasets[d] = data

# %% [markdown]
# # Simulator

# %%
def get_target_stoploss(df, threshold_ratio=(0.04,0.02), use_atr=True, atr_ratio=(2,1), reverse=False):
    if not reverse:
        if use_atr:
            stop_losses = df.low-(df.atr*atr_ratio[1])
            targets = df.close+(df.atr*atr_ratio[0])
        else:
            stop_losses = df.close-df.close*threshold_ratio[1]
            targets = df.close+df.close*threshold_ratio[0]
    else:
        if use_atr:
            stop_losses = df.high+(df.atr*atr_ratio[1])
            targets = df.close-(df.atr*atr_ratio[0])
        else:
            stop_losses = df.close+df.close*threshold_ratio[1]
            targets = df.close-df.close*threshold_ratio[0]

    return targets, stop_losses

def get_decisions_and_prices(x_data, pred, info_dict):
    next_action = 1
    target = -1
    stoploss = -1
    
    if type(x_data.index) != pd.RangeIndex:
        x_data = x_data.reset_index(drop=True)
    
    if type(pred) in (pd.DataFrame, pd.Series):
        pred = pred.to_numpy().ravel()

    use_atr = info_dict['model_use_atr']
    atr_ratio = info_dict['model_ratio']
    threshold_ratio = info_dict['model_ratio']
    reverse = info_dict['model_reverse']
        
    targets, stop_losses = get_target_stoploss(x_data,
                                               use_atr=use_atr,
                                               atr_ratio=atr_ratio,
                                               threshold_ratio=threshold_ratio,
                                               reverse=reverse)
    low_prices = x_data['low'].to_numpy()
    high_prices = x_data['high'].to_numpy()
    
    # Decisions:
    # 1 = buy
    # 0 = hold (default)
    # -1 = sell
    decision = pd.Series(0, index=x_data.index)
    execution_price = pd.Series(0.0, index=x_data.index)

    i = 0
    while True:
        if i>=len(x_data):
            break
        if next_action == 1:
            # Find next buy opportunity
            try:
                next_buy_idx = np.where(pred[i:]==1)[0][0] + i
                target = targets.iloc[next_buy_idx]
                stoploss = stop_losses.iloc[next_buy_idx]
                decision.at[next_buy_idx] = 1
                execution_price.at[next_buy_idx] = x_data.loc[next_buy_idx, 'close']
                i = next_buy_idx+1
                next_action = -1
            except:
                # No more buy opportunties
                break
        else:
            # Find next sell opportunity
            try:
                if not reverse:
                    next_sell_idx = np.where((high_prices[i:]>=target) | (low_prices[i:]<=stoploss))[0][0] + i
                else:
                    next_sell_idx = np.where((low_prices[i:]<=target) | (high_prices[i:]>=stoploss))[0][0] + i
                if x_data.loc[next_sell_idx, 'low'] <= target <= x_data.loc[next_sell_idx, 'high']:
                    execution_price.at[next_sell_idx] = target
                else:
                    execution_price.at[next_sell_idx] = stoploss
                decision.at[next_sell_idx] = -1
                i = next_sell_idx+1
                next_action = 1
            except:
                # No more sell opportunties
                break

    return decision, execution_price

def simulate(in_df, starting_value, trading_fees_percent, trading_fees_buy, trading_fees_sell):
    df = in_df.copy()
    df['value'] = 0.0
    value = starting_value
    fee_multiplier = 1.0 - trading_fees_percent / 100

    for x,r in df.iterrows():
        if r.decision == 1 and value > 0:
            value = ((value-trading_fees_buy) * r.price) * fee_multiplier
            if value < 0:
                break
        elif r.decision == -1 and value > 0:
            value = ((value-trading_fees_sell) / r.price) * fee_multiplier
            if value < 0:
                break
        else:
            break # value is below zero
        df.loc[x,'value'] = value
    return df.value

def run_simulator(X, y, model_use_atr, model_ratio, model_reverse,
                  starting_value=1, trading_fees_percent=0.1,
                  trading_fees_buy=0, trading_fees_sell=0):
    df = X.copy()
    d = dict(model_use_atr=model_use_atr, model_ratio=model_ratio, model_reverse=model_reverse)
    
    decision, execution_price = get_decisions_and_prices(X, y, d)
    
    df['decision'] = decision.values
    df['price'] = execution_price.values
    
    sim_df = df[df['decision']!=0][['decision','price']].copy()
    if len(sim_df) == 0:
        return starting_value
    else:
        sim_df['value'] = simulate(sim_df, starting_value, trading_fees_percent, trading_fees_buy, trading_fees_sell)
        return sim_df[sim_df.decision==-1].value.to_numpy()[-1]

# %% [markdown]
# # Train & Score Classifier with All Columns

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import f1_score, precision_score, recall_score
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import xgboost as xgb

import warnings
warnings.filterwarnings(action='ignore', category=UserWarning)


def score_clf(clf, X, y, model_use_atr=True, model_ratio=(2,1), model_reverse=True):
    pred = clf.predict(X)
    f1 = round(f1_score(y,pred),4)
    pr = round(precision_score(y,pred),4)
    rc = round(recall_score(y,pred),4)
    pf = round(run_simulator(X,pred,model_use_atr,model_ratio,model_reverse), 4)
    return {'f1':f1, 'pr':pr, 'rc':rc, 'pf':pf}

# %%
def add_scores(dname, clf_name, train_scores, test_scores):
    try:
        data_file_df = pd.read_pickle(f'data/data_file_hist_all_cols.pkl')
        if dname in data_file_df.index:
            train_name = f'{clf_name}_train_scores'
            test_name = f'{clf_name}_test_scores'
            data_file_df.at[dname,train_name] = f'{train_scores}'
            data_file_df.at[dname,test_name] = f'{test_scores}'
            data_file_df.to_pickle(f'data/data_file_hist_all_cols.pkl')
    except Exception as e:
        #raise e
        print(f'Exception ({dname},{clf_name}): ', e)

clfs = {
    'gnb' : GaussianNB(),
    'lrc' : LogisticRegression(random_state=42, max_iter=10000),
    'rfc' : RandomForestClassifier(random_state=42, n_jobs=-1),
    'abc' : AdaBoostClassifier(random_state=42),
    'gbc': GradientBoostingClassifier(random_state=42),
    'xgb' : xgb.XGBClassifier(n_jobs=-1, random_state=42, use_label_encoder=False),
    'mlp' : make_pipeline(StandardScaler(),MLPClassifier(random_state=42)),
}

for dname, data in datasets.items():
    print(f'{dname}:')
    for clf_name,clf in clfs.items():
        print(f'  {clf_name}:  ',end='')
        # %time clf.fit(data['X_train'], data['y_train'])
        train_scores = score_clf(clf, data['X_train'], data['y_train'], data['use_atr'], data['ratio'], data['reverse'])
        test_scores = score_clf(clf, data['X_test'], data['y_test'], data['use_atr'], data['ratio'], data['reverse'])
        add_scores(dname, clf_name, train_scores, test_scores)
        print('    Test Scores:', test_scores)
    print(' ')
# Out:
# 20210806g:
#   gnb:  Wall time: 757 ms
#     Test Scores: {'f1': 0.3686, 'pr': 0.2769, 'rc': 0.5513, 'pf': 0.5891}
#   lrc:  Wall time: 2min 5s
#     Test Scores: {'f1': 0.0013, 'pr': 0.3333, 'rc': 0.0006, 'pf': 0.8811}
#   rfc:  Wall time: 15.4 s
#     Test Scores: {'f1': 0.1167, 'pr': 0.5278, 'rc': 0.0656, 'pf': 1.2348}
#   abc:  Wall time: 2min 42s
#     Test Scores: {'f1': 0.0063, 'pr': 0.8824, 'rc': 0.0031, 'pf': 1.0243}
#   gbc:  Wall time: 13min
#     Test Scores: {'f1': 0.0004, 'pr': 0.3333, 'rc': 0.0002, 'pf': 0.9963}
#   xgb:  [20:32:06] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 55.2 s
#     Test Scores: {'f1': 0.1308, 'pr': 0.4057, 'rc': 0.078, 'pf': 1.1658}
#   mlp:  Wall time: 5min 48s
#     Test Scores: {'f1': 0.2053, 'pr': 0.2783, 'rc': 0.1626, 'pf': 0.3146}
#
# 20210806h:
#   gnb:  Wall time: 790 ms
#     Test Scores: {'f1': 0.3285, 'pr': 0.2351, 'rc': 0.545, 'pf': 0.4365}
#   lrc:  Wall time: 1min 42s
#     Test Scores: {'f1': 0.002, 'pr': 0.4, 'rc': 0.001, 'pf': 1.0008}
#   rfc:  Wall time: 14.3 s
#     Test Scores: {'f1': 0.0572, 'pr': 0.4106, 'rc': 0.0307, 'pf': 1.2911}
#   abc:  Wall time: 2min 28s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 12min 55s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 0.9896}
#   xgb:  [20:56:31] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 53.7 s
#     Test Scores: {'f1': 0.0398, 'pr': 0.3556, 'rc': 0.0211, 'pf': 0.9264}
#   mlp:  Wall time: 5min 54s
#     Test Scores: {'f1': 0.1992, 'pr': 0.2436, 'rc': 0.1685, 'pf': 0.4327}
#
# 20210806i:
#   gnb:  Wall time: 800 ms
#     Test Scores: {'f1': 0.4817, 'pr': 0.4254, 'rc': 0.555, 'pf': 0.109}
#   lrc:  Wall time: 1min 19s
#     Test Scores: {'f1': 0.0591, 'pr': 0.5299, 'rc': 0.0313, 'pf': 1.0503}
#   rfc:  Wall time: 15.7 s
#     Test Scores: {'f1': 0.2984, 'pr': 0.4531, 'rc': 0.2224, 'pf': 0.3823}
#   abc:  Wall time: 2min 28s
#     Test Scores: {'f1': 0.1135, 'pr': 0.5097, 'rc': 0.0639, 'pf': 0.5109}
#   gbc:  Wall time: 12min 57s
#     Test Scores: {'f1': 0.0651, 'pr': 0.5201, 'rc': 0.0347, 'pf': 0.84}
#   xgb:  [21:20:48] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 53.9 s
#     Test Scores: {'f1': 0.2535, 'pr': 0.4515, 'rc': 0.1762, 'pf': 0.2179}
#   mlp:  Wall time: 5min 54s
#     Test Scores: {'f1': 0.3768, 'pr': 0.4239, 'rc': 0.3391, 'pf': 0.0495}
#
# 20210806j:
#   gnb:  Wall time: 767 ms
#     Test Scores: {'f1': 0.3818, 'pr': 0.2931, 'rc': 0.5474, 'pf': 0.0353}
#   lrc:  Wall time: 4min 40s
#     Test Scores: {'f1': 0.0258, 'pr': 0.2153, 'rc': 0.0137, 'pf': 0.9508}
#   rfc:  Wall time: 15 s
#     Test Scores: {'f1': 0.0402, 'pr': 0.2484, 'rc': 0.0218, 'pf': 0.7719}
#   abc:  Wall time: 2min 28s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 12min 54s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 0.993}
#   xgb:  [21:48:24] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 53.2 s
#     Test Scores: {'f1': 0.0412, 'pr': 0.2576, 'rc': 0.0224, 'pf': 0.5497}
#   mlp:  Wall time: 5min 49s
#     Test Scores: {'f1': 0.1971, 'pr': 0.2663, 'rc': 0.1565, 'pf': 0.0824}
#
# 20210806k:
#   gnb:  Wall time: 780 ms
#     Test Scores: {'f1': 0.2653, 'pr': 0.1894, 'rc': 0.4424, 'pf': 0.0183}
#   lrc:  Wall time: 4min 51s
#     Test Scores: {'f1': 0.0023, 'pr': 0.129, 'rc': 0.0011, 'pf': 1.0418}
#   rfc:  Wall time: 15.6 s
#     Test Scores: {'f1': 0.0028, 'pr': 0.0794, 'rc': 0.0014, 'pf': 0.9635}
#   abc:  Wall time: 2min 29s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 12min 53s
#     Test Scores: {'f1': 0.0011, 'pr': 0.25, 'rc': 0.0006, 'pf': 1.0026}
#   xgb:  [22:16:05] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 53.3 s
#     Test Scores: {'f1': 0.0117, 'pr': 0.2121, 'rc': 0.006, 'pf': 0.881}
#   mlp:  Wall time: 5min 56s
#     Test Scores: {'f1': 0.1417, 'pr': 0.1858, 'rc': 0.1145, 'pf': 0.092}
#
# 20210806l:
#   gnb:  Wall time: 792 ms
#     Test Scores: {'f1': 0.3112, 'pr': 0.2573, 'rc': 0.3937, 'pf': 0.0558}
#   lrc:  Wall time: 2min 59s
#     Test Scores: {'f1': 0.0022, 'pr': 0.2, 'rc': 0.0011, 'pf': 1.0083}
#   rfc:  Wall time: 15.1 s
#     Test Scores: {'f1': 0.0065, 'pr': 0.1667, 'rc': 0.0033, 'pf': 0.953}
#   abc:  Wall time: 2min 28s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 12min 52s
#     Test Scores: {'f1': 0.0004, 'pr': 0.2, 'rc': 0.0002, 'pf': 0.9965}
#   xgb:  [22:42:01] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 55.8 s
#     Test Scores: {'f1': 0.0126, 'pr': 0.2871, 'rc': 0.0064, 'pf': 0.9192}
#   mlp:  Wall time: 5min 52s
#     Test Scores: {'f1': 0.1955, 'pr': 0.2404, 'rc': 0.1647, 'pf': 0.0398}

# %% [markdown]
# # Limit to 3 lookbacks

# %%
import re

def get_columns(X_train,lookbacks):
    # Drop columns with lookbacks equal to or greater than X
    columns = list(X_train.columns)
    for c in X_train.columns:
        if m := re.match(r'^.*_([0-9]+)$', c):
            if int(m[1]) > lookbacks:
                columns.remove(c)
    return columns


def add_scores(dname, clf_name, train_scores, test_scores):
    try:
        data_file_df = pd.read_pickle(f'data/data_file_hist_some_cols.pkl')
        if dname in data_file_df.index:
            train_name = f'{clf_name}_train_scores'
            test_name = f'{clf_name}_test_scores'
            data_file_df.at[dname,train_name] = f'{train_scores}'
            data_file_df.at[dname,test_name] = f'{test_scores}'
            data_file_df.to_pickle(f'data/data_file_hist_some_cols.pkl')
    except Exception as e:
        #raise e
        print(f'Exception ({dname},{clf_name}): ', e)

clfs = {
    'gnb' : GaussianNB(),
    'lrc' : LogisticRegression(random_state=42, max_iter=10000),
    'rfc' : RandomForestClassifier(random_state=42, n_jobs=-1),
    'abc' : AdaBoostClassifier(random_state=42),
    'gbc': GradientBoostingClassifier(random_state=42),
    'xgb' : xgb.XGBClassifier(n_jobs=-1, random_state=42, use_label_encoder=False),
    'mlp' : make_pipeline(StandardScaler(),MLPClassifier(random_state=42)),
}

for dname, data in datasets.items():
    print(f'{dname}:')
    
    columns = get_columns(data['X_train'],lookbacks=3)
    data['X_train'] = data['X_train'][columns]
    data['X_test'] = data['X_test'][columns]
    
    for clf_name,clf in clfs.items():
        print(f'  {clf_name}:  ',end='')
        # %time clf.fit(data['X_train'], data['y_train'])
        train_scores = score_clf(clf, data['X_train'], data['y_train'], data['use_atr'], data['ratio'], data['reverse'])
        test_scores = score_clf(clf, data['X_test'], data['y_test'], data['use_atr'], data['ratio'], data['reverse'])
        add_scores(dname, clf_name, train_scores, test_scores)
        print('    Test Scores:', test_scores)
    print(' ')
# Out:
# 20210806a:
#   gnb:  Wall time: 219 ms
#     Test Scores: {'f1': 0.3709, 'pr': 0.3565, 'rc': 0.3866, 'pf': 0.28}
#   lrc:  Wall time: 37.8 s
#     Test Scores: {'f1': 0.0068, 'pr': 0.2973, 'rc': 0.0034, 'pf': 0.9901}
#   rfc:  Wall time: 6.33 s
#     Test Scores: {'f1': 0.1973, 'pr': 0.3709, 'rc': 0.1344, 'pf': 0.4862}
#   abc:  Wall time: 40.4 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 3min 29s
#     Test Scores: {'f1': 0.0003, 'pr': 0.5, 'rc': 0.0002, 'pf': 0.993}
#   xgb:  [22:54:06] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 16.7 s
#     Test Scores: {'f1': 0.1308, 'pr': 0.3145, 'rc': 0.0826, 'pf': 0.4693}
#   mlp:  Wall time: 2min 27s
#     Test Scores: {'f1': 0.1447, 'pr': 0.3541, 'rc': 0.0909, 'pf': 0.2577}
#
# 20210806b:
#   gnb:  Wall time: 233 ms
#     Test Scores: {'f1': 0.2737, 'pr': 0.2234, 'rc': 0.3534, 'pf': 0.1115}
#   lrc:  Wall time: 52.3 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 0.9955}
#   rfc:  Wall time: 7.33 s
#     Test Scores: {'f1': 0.0243, 'pr': 0.2825, 'rc': 0.0127, 'pf': 0.9578}
#   abc:  Wall time: 40.7 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 3min 30s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   xgb:  [23:02:19] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 15.1 s
#     Test Scores: {'f1': 0.0343, 'pr': 0.3532, 'rc': 0.018, 'pf': 0.9437}
#   mlp:  Wall time: 2min 23s
#     Test Scores: {'f1': 0.0372, 'pr': 0.221, 'rc': 0.0203, 'pf': 0.6233}
#
# 20210806c:
#   gnb:  Wall time: 212 ms
#     Test Scores: {'f1': 0.361, 'pr': 0.2692, 'rc': 0.5478, 'pf': 0.0303}
#   lrc:  Wall time: 48.3 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 0.9955}
#   rfc:  Wall time: 7.74 s
#     Test Scores: {'f1': 0.024, 'pr': 0.3602, 'rc': 0.0124, 'pf': 0.9326}
#   abc:  Wall time: 40.5 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 3min 28s
#     Test Scores: {'f1': 0.0013, 'pr': 0.1765, 'rc': 0.0006, 'pf': 0.9754}
#   xgb:  [23:10:24] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 15.1 s
#     Test Scores: {'f1': 0.0211, 'pr': 0.3188, 'rc': 0.0109, 'pf': 0.8491}
#   mlp:  Wall time: 2min 6s
#     Test Scores: {'f1': 0.123, 'pr': 0.2915, 'rc': 0.078, 'pf': 0.3574}
#
# 20210806d:
#   gnb:  Wall time: 207 ms
#     Test Scores: {'f1': 0.4233, 'pr': 0.3739, 'rc': 0.4879, 'pf': 0.1768}
#   lrc:  Wall time: 34.4 s
#     Test Scores: {'f1': 0.0044, 'pr': 0.4412, 'rc': 0.0022, 'pf': 1.2377}
#   rfc:  Wall time: 7.23 s
#     Test Scores: {'f1': 0.1763, 'pr': 0.3971, 'rc': 0.1133, 'pf': 0.5251}
#   abc:  Wall time: 40.5 s
#     Test Scores: {'f1': 0.0009, 'pr': 0.4286, 'rc': 0.0004, 'pf': 0.9636}
#   gbc:  Wall time: 3min 27s
#     Test Scores: {'f1': 0.0009, 'pr': 0.5, 'rc': 0.0004, 'pf': 0.9863}
#   xgb:  [23:17:54] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 16 s
#     Test Scores: {'f1': 0.1624, 'pr': 0.3909, 'rc': 0.1025, 'pf': 0.5276}
#   mlp:  Wall time: 2min 27s
#     Test Scores: {'f1': 0.1965, 'pr': 0.3634, 'rc': 0.1346, 'pf': 0.2081}
#
# 20210806e:
#   gnb:  Wall time: 204 ms
#     Test Scores: {'f1': 0.2225, 'pr': 0.1593, 'rc': 0.369, 'pf': 0.8235}
#   lrc:  Wall time: 18.2 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 0.921}
#   rfc:  Wall time: 8.47 s
#     Test Scores: {'f1': 0.0071, 'pr': 0.2647, 'rc': 0.0036, 'pf': 1.1083}
#   abc:  Wall time: 40.2 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 3min 29s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   xgb:  [23:25:27] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 13.7 s
#     Test Scores: {'f1': 0.0391, 'pr': 0.3023, 'rc': 0.0209, 'pf': 1.0338}
#   mlp:  Wall time: 2min
#     Test Scores: {'f1': 0.0458, 'pr': 0.1852, 'rc': 0.0261, 'pf': 1.0753}
#
# 20210806f:
#   gnb:  Wall time: 213 ms
#     Test Scores: {'f1': 0.2101, 'pr': 0.1473, 'rc': 0.3663, 'pf': 0.7506}
#   lrc:  Wall time: 28.3 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 0.9563}
#   rfc:  Wall time: 7.68 s
#     Test Scores: {'f1': 0.0036, 'pr': 0.1739, 'rc': 0.0018, 'pf': 1.0228}
#   abc:  Wall time: 40.5 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 3min 28s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   xgb:  [23:32:36] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 14 s
#     Test Scores: {'f1': 0.0174, 'pr': 0.2703, 'rc': 0.009, 'pf': 1.0784}
#   mlp:  Wall time: 2min 27s
#     Test Scores: {'f1': 0.0535, 'pr': 0.1786, 'rc': 0.0315, 'pf': 0.9361}
#
# 20210806g:
#   gnb:  Wall time: 216 ms
#     Test Scores: {'f1': 0.3713, 'pr': 0.283, 'rc': 0.5396, 'pf': 0.6536}
#   lrc:  Wall time: 19.5 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   rfc:  Wall time: 6.59 s
#     Test Scores: {'f1': 0.1706, 'pr': 0.4751, 'rc': 0.1039, 'pf': 1.2846}
#   abc:  Wall time: 40.4 s
#     Test Scores: {'f1': 0.0004, 'pr': 1.0, 'rc': 0.0002, 'pf': 1.0092}
#   gbc:  Wall time: 3min 28s
#     Test Scores: {'f1': 0.0004, 'pr': 0.2, 'rc': 0.0002, 'pf': 0.9949}
#   xgb:  [23:40:01] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 15.6 s
#     Test Scores: {'f1': 0.157, 'pr': 0.3741, 'rc': 0.0993, 'pf': 0.7891}
#   mlp:  Wall time: 2min 10s
#     Test Scores: {'f1': 0.0885, 'pr': 0.3297, 'rc': 0.0511, 'pf': 0.708}
#
# 20210806h:
#   gnb:  Wall time: 215 ms
#     Test Scores: {'f1': 0.3245, 'pr': 0.2409, 'rc': 0.4969, 'pf': 0.4987}
#   lrc:  Wall time: 24.3 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 0.9437}
#   rfc:  Wall time: 7.16 s
#     Test Scores: {'f1': 0.1007, 'pr': 0.4481, 'rc': 0.0568, 'pf': 1.0838}
#   abc:  Wall time: 40.5 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 3min 28s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   xgb:  [23:47:18] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 16 s
#     Test Scores: {'f1': 0.0948, 'pr': 0.3756, 'rc': 0.0543, 'pf': 1.0579}
#   mlp:  Wall time: 2min 29s
#     Test Scores: {'f1': 0.0953, 'pr': 0.2848, 'rc': 0.0572, 'pf': 0.6002}
#
# 20210806i:
#   gnb:  Wall time: 230 ms
#     Test Scores: {'f1': 0.486, 'pr': 0.4305, 'rc': 0.5581, 'pf': 0.1295}
#   lrc:  Wall time: 11.5 s
#     Test Scores: {'f1': 0.0297, 'pr': 0.5708, 'rc': 0.0152, 'pf': 1.6651}
#   rfc:  Wall time: 7.34 s
#     Test Scores: {'f1': 0.3219, 'pr': 0.4481, 'rc': 0.2512, 'pf': 0.2441}
#   abc:  Wall time: 40.6 s
#     Test Scores: {'f1': 0.1097, 'pr': 0.4722, 'rc': 0.062, 'pf': 0.5748}
#   gbc:  Wall time: 3min 28s
#     Test Scores: {'f1': 0.0896, 'pr': 0.5241, 'rc': 0.049, 'pf': 0.6239}
#   xgb:  [23:54:51] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 14.9 s
#     Test Scores: {'f1': 0.3195, 'pr': 0.4459, 'rc': 0.2489, 'pf': 0.2391}
#   mlp:  Wall time: 2min 27s
#     Test Scores: {'f1': 0.2728, 'pr': 0.4186, 'rc': 0.2023, 'pf': 0.0998}
#
# 20210806j:
#   gnb:  Wall time: 207 ms
#     Test Scores: {'f1': 0.3402, 'pr': 0.2908, 'rc': 0.4097, 'pf': 0.0388}
#   lrc:  Wall time: 1min 7s
#     Test Scores: {'f1': 0.007, 'pr': 0.125, 'rc': 0.0036, 'pf': 0.9787}
#   rfc:  Wall time: 6.95 s
#     Test Scores: {'f1': 0.0637, 'pr': 0.2591, 'rc': 0.0363, 'pf': 0.7818}
#   abc:  Wall time: 40.7 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 3min 27s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   xgb:  [00:03:17] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 14.4 s
#     Test Scores: {'f1': 0.0561, 'pr': 0.3071, 'rc': 0.0309, 'pf': 0.7762}
#   mlp:  Wall time: 2min 30s
#     Test Scores: {'f1': 0.1041, 'pr': 0.2862, 'rc': 0.0636, 'pf': 0.3291}
#
# 20210806k:
#   gnb:  Wall time: 218 ms
#     Test Scores: {'f1': 0.1594, 'pr': 0.2136, 'rc': 0.1271, 'pf': 0.2785}
#   lrc:  Wall time: 55.1 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1.0017}
#   rfc:  Wall time: 8.23 s
#     Test Scores: {'f1': 0.0131, 'pr': 0.1481, 'rc': 0.0069, 'pf': 0.9062}
#   abc:  Wall time: 40.5 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 3min 28s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   xgb:  [00:11:27] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 13.9 s
#     Test Scores: {'f1': 0.0187, 'pr': 0.2394, 'rc': 0.0097, 'pf': 0.9264}
#   mlp:  Wall time: 2min 30s
#     Test Scores: {'f1': 0.0551, 'pr': 0.1871, 'rc': 0.0323, 'pf': 0.4509}
#
# 20210806l:
#   gnb:  Wall time: 214 ms
#     Test Scores: {'f1': 0.2909, 'pr': 0.2572, 'rc': 0.3348, 'pf': 0.0695}
#   lrc:  Wall time: 49.6 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 0.9955}
#   rfc:  Wall time: 7.35 s
#     Test Scores: {'f1': 0.0187, 'pr': 0.2115, 'rc': 0.0098, 'pf': 0.8634}
#   abc:  Wall time: 40.4 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 3min 28s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   xgb:  [00:19:36] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 13.7 s
#     Test Scores: {'f1': 0.01, 'pr': 0.284, 'rc': 0.0051, 'pf': 0.9259}
#   mlp:  Wall time: 2min 6s
#     Test Scores: {'f1': 0.0919, 'pr': 0.2816, 'rc': 0.0549, 'pf': 0.4338}

# %% [markdown]
# # No lookbacks

# %%
def add_scores(dname, clf_name, train_scores, test_scores):
    try:
        data_file_df = pd.read_pickle(f'data/data_file_hist_no_lkbk.pkl')
        if dname in data_file_df.index:
            train_name = f'{clf_name}_train_scores'
            test_name = f'{clf_name}_test_scores'
            data_file_df.at[dname,train_name] = f'{train_scores}'
            data_file_df.at[dname,test_name] = f'{test_scores}'
            data_file_df.to_pickle(f'data/data_file_hist_no_lkbk.pkl')
    except Exception as e:
        #raise e
        print(f'Exception ({dname},{clf_name}): ', e)

clfs = {
    'gnb' : GaussianNB(),
    'lrc' : LogisticRegression(random_state=42, max_iter=10000),
    'rfc' : RandomForestClassifier(random_state=42, n_jobs=-1),
    'abc' : AdaBoostClassifier(random_state=42),
    'gbc': GradientBoostingClassifier(random_state=42),
    'xgb' : xgb.XGBClassifier(n_jobs=-1, random_state=42, use_label_encoder=False),
    'mlp' : make_pipeline(StandardScaler(),MLPClassifier(random_state=42)),
}

for dname, data in datasets.items():
    print(f'{dname}:')
    
    columns = get_columns(data['X_train'],lookbacks=0)
    data['X_train'] = data['X_train'][columns]
    data['X_test'] = data['X_test'][columns]
    
    for clf_name,clf in clfs.items():
        print(f'  {clf_name}:  ',end='')
        # %time clf.fit(data['X_train'], data['y_train'])
        train_scores = score_clf(clf, data['X_train'], data['y_train'], data['use_atr'], data['ratio'], data['reverse'])
        test_scores = score_clf(clf, data['X_test'], data['y_test'], data['use_atr'], data['ratio'], data['reverse'])
        add_scores(dname, clf_name, train_scores, test_scores)
        print('    Test Scores:', test_scores)
    print(' ')
# Out:
# 20210806a:
#   gnb:  Wall time: 62.8 ms
#     Test Scores: {'f1': 0.0217, 'pr': 0.3077, 'rc': 0.0113, 'pf': 0.7722}
#   lrc:  Wall time: 833 ms
#     Test Scores: {'f1': 0.0016, 'pr': 0.2083, 'rc': 0.0008, 'pf': 1.0036}
#   rfc:  Wall time: 3.26 s
#     Test Scores: {'f1': 0.211, 'pr': 0.3804, 'rc': 0.146, 'pf': 0.4542}
#   abc:  Wall time: 10.8 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 53.3 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   xgb:  [00:23:14] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 5.6 s
#     Test Scores: {'f1': 0.1685, 'pr': 0.3605, 'rc': 0.11, 'pf': 0.5238}
#   mlp:  Wall time: 54.7 s
#     Test Scores: {'f1': 0.1116, 'pr': 0.4145, 'rc': 0.0645, 'pf': 0.5697}
#
# 20210806b:
#   gnb:  Wall time: 60.9 ms
#     Test Scores: {'f1': 0.0148, 'pr': 0.2586, 'rc': 0.0076, 'pf': 0.899}
#   lrc:  Wall time: 843 ms
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   rfc:  Wall time: 3.24 s
#     Test Scores: {'f1': 0.038, 'pr': 0.3008, 'rc': 0.0203, 'pf': 0.8503}
#   abc:  Wall time: 10.7 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 53.4 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   xgb:  [00:25:31] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 5.21 s
#     Test Scores: {'f1': 0.0153, 'pr': 0.265, 'rc': 0.0079, 'pf': 0.9829}
#   mlp:  Wall time: 1min 8s
#     Test Scores: {'f1': 0.0255, 'pr': 0.4031, 'rc': 0.0132, 'pf': 0.9854}
#
# 20210806c:
#   gnb:  Wall time: 75.8 ms
#     Test Scores: {'f1': 0.182, 'pr': 0.2573, 'rc': 0.1408, 'pf': 0.1162}
#   lrc:  Wall time: 826 ms
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   rfc:  Wall time: 3.85 s
#     Test Scores: {'f1': 0.042, 'pr': 0.3302, 'rc': 0.0224, 'pf': 0.8376}
#   abc:  Wall time: 10.7 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 53.6 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   xgb:  [00:28:06] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 5.14 s
#     Test Scores: {'f1': 0.0222, 'pr': 0.2857, 'rc': 0.0115, 'pf': 0.8624}
#   mlp:  Wall time: 1min 16s
#     Test Scores: {'f1': 0.0117, 'pr': 0.28, 'rc': 0.006, 'pf': 0.8997}
#
# 20210806d:
#   gnb:  Wall time: 69.8 ms
#     Test Scores: {'f1': 0.0753, 'pr': 0.3689, 'rc': 0.0419, 'pf': 0.3907}
#   lrc:  Wall time: 951 ms
#     Test Scores: {'f1': 0.0017, 'pr': 0.6, 'rc': 0.0009, 'pf': 1.0045}
#   rfc:  Wall time: 3.44 s
#     Test Scores: {'f1': 0.1975, 'pr': 0.3904, 'rc': 0.1322, 'pf': 0.4182}
#   abc:  Wall time: 10.7 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 53.2 s
#     Test Scores: {'f1': 0.0026, 'pr': 0.6, 'rc': 0.0013, 'pf': 1.0126}
#   xgb:  [00:30:46] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 5.17 s
#     Test Scores: {'f1': 0.1707, 'pr': 0.3983, 'rc': 0.1086, 'pf': 0.4662}
#   mlp:  Wall time: 1min 24s
#     Test Scores: {'f1': 0.1145, 'pr': 0.4266, 'rc': 0.0662, 'pf': 0.4577}
#
# 20210806e:
#   gnb:  Wall time: 54.9 ms
#     Test Scores: {'f1': 0.0102, 'pr': 0.1857, 'rc': 0.0052, 'pf': 1.1821}
#   lrc:  Wall time: 1.02 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   rfc:  Wall time: 3.68 s
#     Test Scores: {'f1': 0.0125, 'pr': 0.2222, 'rc': 0.0064, 'pf': 1.0851}
#   abc:  Wall time: 10.7 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 53.6 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   xgb:  [00:33:34] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 5.18 s
#     Test Scores: {'f1': 0.0627, 'pr': 0.4421, 'rc': 0.0338, 'pf': 1.0233}
#   mlp:  Wall time: 1min 23s
#     Test Scores: {'f1': 0.0179, 'pr': 0.2805, 'rc': 0.0092, 'pf': 1.3758}
#
# 20210806f:
#   gnb:  Wall time: 103 ms
#     Test Scores: {'f1': 0.0314, 'pr': 0.1054, 'rc': 0.0184, 'pf': 0.8332}
#   lrc:  Wall time: 968 ms
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   rfc:  Wall time: 4.48 s
#     Test Scores: {'f1': 0.0071, 'pr': 0.2667, 'rc': 0.0036, 'pf': 1.0153}
#   abc:  Wall time: 10.7 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 53.3 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   xgb:  [00:36:16] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 5.11 s
#     Test Scores: {'f1': 0.0731, 'pr': 0.3434, 'rc': 0.0409, 'pf': 0.8959}
#   mlp:  Wall time: 1min 23s
#     Test Scores: {'f1': 0.007, 'pr': 0.1633, 'rc': 0.0036, 'pf': 1.099}
#
# 20210806g:
#   gnb:  Wall time: 65.8 ms
#     Test Scores: {'f1': 0.0609, 'pr': 0.3306, 'rc': 0.0335, 'pf': 1.1278}
#   lrc:  Wall time: 881 ms
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   rfc:  Wall time: 3.23 s
#     Test Scores: {'f1': 0.1669, 'pr': 0.4138, 'rc': 0.1046, 'pf': 1.0505}
#   abc:  Wall time: 10.7 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 53.2 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 0.9763}
#   xgb:  [00:38:58] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 5.08 s
#     Test Scores: {'f1': 0.1447, 'pr': 0.4017, 'rc': 0.0882, 'pf': 0.9371}
#   mlp:  Wall time: 1min 27s
#     Test Scores: {'f1': 0.0823, 'pr': 0.3982, 'rc': 0.0459, 'pf': 1.2196}
#
# 20210806h:
#   gnb:  Wall time: 62.9 ms
#     Test Scores: {'f1': 0.0455, 'pr': 0.2282, 'rc': 0.0253, 'pf': 0.8826}
#   lrc:  Wall time: 701 ms
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 0.992}
#   rfc:  Wall time: 3.67 s
#     Test Scores: {'f1': 0.1002, 'pr': 0.401, 'rc': 0.0572, 'pf': 1.1227}
#   abc:  Wall time: 10.7 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 53.3 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 0.9937}
#   xgb:  [00:41:45] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 6.38 s
#     Test Scores: {'f1': 0.0986, 'pr': 0.3367, 'rc': 0.0577, 'pf': 1.071}
#   mlp:  Wall time: 1min 24s
#     Test Scores: {'f1': 0.0588, 'pr': 0.3686, 'rc': 0.032, 'pf': 0.9531}
#
# 20210806i:
#   gnb:  Wall time: 67.8 ms
#     Test Scores: {'f1': 0.2811, 'pr': 0.4655, 'rc': 0.2013, 'pf': 0.1774}
#   lrc:  Wall time: 1.04 s
#     Test Scores: {'f1': 0.0161, 'pr': 0.6204, 'rc': 0.0082, 'pf': 1.321}
#   rfc:  Wall time: 4.62 s
#     Test Scores: {'f1': 0.33, 'pr': 0.4342, 'rc': 0.2662, 'pf': 0.173}
#   abc:  Wall time: 10.7 s
#     Test Scores: {'f1': 0.1327, 'pr': 0.4781, 'rc': 0.077, 'pf': 0.5312}
#   gbc:  Wall time: 53.6 s
#     Test Scores: {'f1': 0.1138, 'pr': 0.4925, 'rc': 0.0644, 'pf': 0.4908}
#   xgb:  [00:44:40] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 6.46 s
#     Test Scores: {'f1': 0.2855, 'pr': 0.4452, 'rc': 0.2101, 'pf': 0.2822}
#   mlp:  Wall time: 1min 34s
#     Test Scores: {'f1': 0.2606, 'pr': 0.4477, 'rc': 0.1838, 'pf': 0.2079}
#
# 20210806j:
#   gnb:  Wall time: 61.8 ms
#     Test Scores: {'f1': 0.1299, 'pr': 0.2583, 'rc': 0.0868, 'pf': 0.1997}
#   lrc:  Wall time: 3.16 s
#     Test Scores: {'f1': 0.0037, 'pr': 0.0885, 'rc': 0.0019, 'pf': 0.9381}
#   rfc:  Wall time: 3.9 s
#     Test Scores: {'f1': 0.0935, 'pr': 0.2588, 'rc': 0.0571, 'pf': 0.5651}
#   abc:  Wall time: 10.7 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 53.3 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   xgb:  [00:47:47] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 6.33 s
#     Test Scores: {'f1': 0.0632, 'pr': 0.252, 'rc': 0.0362, 'pf': 0.7515}
#   mlp:  Wall time: 1min 32s
#     Test Scores: {'f1': 0.0425, 'pr': 0.354, 'rc': 0.0226, 'pf': 0.8883}
#
# 20210806k:
#   gnb:  Wall time: 59.9 ms
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 0.991}
#   lrc:  Wall time: 2.86 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1.0198}
#   rfc:  Wall time: 4.06 s
#     Test Scores: {'f1': 0.0302, 'pr': 0.2127, 'rc': 0.0163, 'pf': 0.8527}
#   abc:  Wall time: 10.7 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 53.3 s
#     Test Scores: {'f1': 0.0006, 'pr': 1.0, 'rc': 0.0003, 'pf': 1.0081}
#   xgb:  [00:50:43] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 6.45 s
#     Test Scores: {'f1': 0.0236, 'pr': 0.1442, 'rc': 0.0129, 'pf': 0.8525}
#   mlp:  Wall time: 55.8 s
#     Test Scores: {'f1': 0.0011, 'pr': 0.1818, 'rc': 0.0006, 'pf': 1.0007}
#
# 20210806l:
#   gnb:  Wall time: 77.8 ms
#     Test Scores: {'f1': 0.0152, 'pr': 0.2917, 'rc': 0.0078, 'pf': 0.8603}
#   lrc:  Wall time: 2.19 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   rfc:  Wall time: 4.2 s
#     Test Scores: {'f1': 0.0485, 'pr': 0.2874, 'rc': 0.0265, 'pf': 0.7561}
#   abc:  Wall time: 10.8 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0, 'pf': 1}
#   gbc:  Wall time: 53.4 s
#     Test Scores: {'f1': 0.0004, 'pr': 0.3333, 'rc': 0.0002, 'pf': 1.001}
#   xgb:  [00:53:03] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 5.74 s
#     Test Scores: {'f1': 0.0185, 'pr': 0.2945, 'rc': 0.0096, 'pf': 0.929}
#   mlp:  Wall time: 1min 14s
#     Test Scores: {'f1': 0.0088, 'pr': 0.2778, 'rc': 0.0044, 'pf': 0.9154}
