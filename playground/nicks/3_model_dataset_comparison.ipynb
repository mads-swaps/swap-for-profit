# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Load Datasets

# %%
def train_test_split(X, y, train_idx=None, test_idx=None):
    X_train = X.loc[train_idx]
    y_train = y.loc[train_idx]
    X_test = X.loc[test_idx]
    y_test = y.loc[test_idx]
    return (X_train, y_train, X_test, y_test)

def load_split_data(suffix=None, split=False, window=14):
    if suffix==None:
        suffix='DEFAULT'
    try:
        X = pd.read_pickle(f'data/X_{suffix}.pkl')
        y = pd.read_pickle(f'data/y_{suffix}.pkl')
    except:
        X, y, _ = build_Xy(df, window=window, use_atr=True, atr_ratio=(20,5), reverse=False, debug=True)
        X.to_pickle(f'data/X_{suffix}.pkl')
        y.to_pickle(f'data/y_{suffix}.pkl')
        
    if split:
        X_train, y_train, X_test, y_test = train_test_split(X, y, X.loc['2018':'2020'].index, X.loc['2021':].index)
        return X_train, y_train, X_test, y_test
    else:
        return X, y
    
dataset_suffixes = [
    '20210806a',
    '20210806b',
    '20210806c',
    '20210806d',
    '20210806e',
    '20210806f',
    '20210806g',
    '20210806h',
    '20210806i',
    '20210806j',
    '20210806k',
    '20210806l',
]

datasets = {}

for d in dataset_suffixes:
    X_train, y_train, X_test, y_test = load_split_data(suffix=d, split=True)
    data = dict(X_train = X_train,
                y_train = y_train,
                X_test = X_test,
                y_test = y_test
               )
    datasets[d] = data

# %% [markdown]
# # Train & Score Classifier with All Columns

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import f1_score, precision_score, recall_score
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import xgboost as xgb

import warnings
warnings.filterwarnings(action='ignore', category=UserWarning)


def score_clf(clf, X, y):
    f1 = round(f1_score(y,clf.predict(X)),4)
    pr = round(precision_score(y,clf.predict(X)),4)
    rc = round(recall_score(y,clf.predict(X)),4)
    return {'f1':f1, 'pr':pr, 'rc':rc}

# %%
def add_scores(dname, clf_name, train_scores, test_scores):
    try:
        data_file_df = pd.read_pickle(f'data/data_file_hist_all_cols.pkl')
        if dname in data_file_df.index:
            train_name = f'{clf_name}_train_scores'
            test_name = f'{clf_name}_test_scores'
            data_file_df.at[dname,train_name] = f'{train_scores}'
            data_file_df.at[dname,test_name] = f'{test_scores}'
            data_file_df.to_pickle(f'data/data_file_hist_all_cols.pkl')
    except Exception as e:
        #raise e
        print(f'Exception ({dname},{clf_name}): ', e)

clfs = {
    'gnb' : GaussianNB(),
    'lrc' : LogisticRegression(random_state=42, max_iter=10000),
    'rfc' : RandomForestClassifier(random_state=42, n_jobs=-1),
    'abc' : AdaBoostClassifier(random_state=42),
    'gbc': GradientBoostingClassifier(random_state=42),
    'xgb' : xgb.XGBClassifier(n_jobs=-1, random_state=42, use_label_encoder=False),
    'mlp' : make_pipeline(StandardScaler(),MLPClassifier(random_state=42)),
}

for dname, data in datasets.items():
    print(f'{dname}:')
    for clf_name,clf in clfs.items():
        print(f'  {clf_name}:  ',end='')
        # %time clf.fit(data['X_train'], data['y_train'])
        train_scores = score_clf(clf, data['X_train'], data['y_train'])
        test_scores = score_clf(clf, data['X_test'], data['y_test'])
        add_scores(dname, clf_name, train_scores, test_scores)
        print('    Test Scores:', test_scores)
    print(' ')
# Out:
# 20210806a:
#   gnb:  Wall time: 793 ms
#     Test Scores: {'f1': 0.397, 'pr': 0.3591, 'rc': 0.444}
#
#   lrc:  Wall time: 2min 30s
#     Test Scores: {'f1': 0.0226, 'pr': 0.3024, 'rc': 0.0117}
#
#   rfc:  Wall time: 11.2 s
#     Test Scores: {'f1': 0.1671, 'pr': 0.3644, 'rc': 0.1084}
#
#   abc:  Wall time: 2min 27s
#     Test Scores: {'f1': 0.0031, 'pr': 0.5263, 'rc': 0.0016}
#
#   gbc:  Wall time: 12min 52s
#     Test Scores: {'f1': 0.0006, 'pr': 0.1333, 'rc': 0.0003}
#
#   xgb:  [14:01:22] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 41.8 s
#     Test Scores: {'f1': 0.1025, 'pr': 0.3536, 'rc': 0.0599}
#
#   mlp:  Wall time: 4min 38s
#     Test Scores: {'f1': 0.2724, 'pr': 0.3403, 'rc': 0.2272}
#
# 20210806b:
#   gnb:  Wall time: 813 ms
#     Test Scores: {'f1': 0.284, 'pr': 0.224, 'rc': 0.3879}
#
#   lrc:  Wall time: 2min 31s
#     Test Scores: {'f1': 0.0015, 'pr': 0.2143, 'rc': 0.0008}
#
#   rfc:  Wall time: 13.1 s
#     Test Scores: {'f1': 0.0109, 'pr': 0.275, 'rc': 0.0056}
#
#   abc:  Wall time: 2min 30s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#
#   gbc:  Wall time: 12min 54s
#     Test Scores: {'f1': 0.001, 'pr': 0.3333, 'rc': 0.0005}
#
#   xgb:  [14:25:24] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 42.6 s
#     Test Scores: {'f1': 0.0147, 'pr': 0.229, 'rc': 0.0076}
#
#   mlp:  Wall time: 4min 37s
#     Test Scores: {'f1': 0.1682, 'pr': 0.2316, 'rc': 0.1321}
#
# 20210806c:
#   gnb:  Wall time: 752 ms
#     Test Scores: {'f1': 0.3507, 'pr': 0.2666, 'rc': 0.5122}
#
#   lrc:  Wall time: 2min 32s
#     Test Scores: {'f1': 0.0009, 'pr': 0.25, 'rc': 0.0004}
#
#   rfc:  Wall time: 13.2 s
#     Test Scores: {'f1': 0.0163, 'pr': 0.3714, 'rc': 0.0083}
#
#   abc:  Wall time: 2min 28s
#     Test Scores: {'f1': 0.0009, 'pr': 0.1538, 'rc': 0.0004}
#
#   gbc:  Wall time: 12min 41s
#     Test Scores: {'f1': 0.0013, 'pr': 0.2727, 'rc': 0.0006}
#
#   xgb:  [14:49:10] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 40.2 s
#     Test Scores: {'f1': 0.0137, 'pr': 0.2426, 'rc': 0.007}
#
#   mlp:  Wall time: 4min 32s
#     Test Scores: {'f1': 0.2008, 'pr': 0.2588, 'rc': 0.164}
#
# 20210806d:
#   gnb:  Wall time: 798 ms
#     Test Scores: {'f1': 0.4461, 'pr': 0.3701, 'rc': 0.5615}
#
#   lrc:  Wall time: 1min 17s
#     Test Scores: {'f1': 0.0135, 'pr': 0.4393, 'rc': 0.0069}
#
#   rfc:  Wall time: 12.8 s
#     Test Scores: {'f1': 0.1019, 'pr': 0.4452, 'rc': 0.0575}
#
#   abc:  Wall time: 2min 28s
#     Test Scores: {'f1': 0.0058, 'pr': 0.3774, 'rc': 0.0029}
#
#   gbc:  Wall time: 13min 5s
#     Test Scores: {'f1': 0.0006, 'pr': 0.25, 'rc': 0.0003}
#
#   xgb:  [15:11:59] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 42.8 s
#     Test Scores: {'f1': 0.1153, 'pr': 0.4171, 'rc': 0.0669}
#
#   mlp:  Wall time: 4min 42s
#     Test Scores: {'f1': 0.3059, 'pr': 0.3735, 'rc': 0.2591}
#
# 20210806e:
#   gnb:  Wall time: 805 ms
#     Test Scores: {'f1': 0.2406, 'pr': 0.1549, 'rc': 0.5386}
#
#   lrc:  Wall time: 2min 2s
#     Test Scores: {'f1': 0.0016, 'pr': 0.25, 'rc': 0.0008}
#
#   rfc:  Wall time: 14 s
#     Test Scores: {'f1': 0.0016, 'pr': 0.2, 'rc': 0.0008}
#
#   abc:  Wall time: 2min 33s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#
#   gbc:  Wall time: 13min 10s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#
#   xgb:  [15:35:59] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 43.3 s
#     Test Scores: {'f1': 0.0168, 'pr': 0.1618, 'rc': 0.0088}
#
#   mlp:  Wall time: 4min 49s
#     Test Scores: {'f1': 0.133, 'pr': 0.1555, 'rc': 0.1162}
#
# 20210806f:
#   gnb:  Wall time: 807 ms
#     Test Scores: {'f1': 0.2233, 'pr': 0.1407, 'rc': 0.5407}
#
#   lrc:  Wall time: 1min 55s
#     Test Scores: {'f1': 0.0027, 'pr': 0.3333, 'rc': 0.0013}
#
#   rfc:  Wall time: 14 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#
#   abc:  Wall time: 2min 31s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#
#   gbc:  Wall time: 13min
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#
#   xgb:  [15:59:45] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 40.6 s
#     Test Scores: {'f1': 0.0243, 'pr': 0.3373, 'rc': 0.0126}
#
#   mlp:  Wall time: 4min 46s
#     Test Scores: {'f1': 0.1335, 'pr': 0.1533, 'rc': 0.1182}
#
# 20210806g:
#   gnb:  Wall time: 784 ms
#     Test Scores: {'f1': 0.3686, 'pr': 0.2769, 'rc': 0.5513}
#
#   lrc:  Wall time: 1min 58s
#     Test Scores: {'f1': 0.0013, 'pr': 0.3333, 'rc': 0.0006}
#
#   rfc:  Wall time: 12.1 s
#     Test Scores: {'f1': 0.1167, 'pr': 0.5278, 'rc': 0.0656}
#
#   abc:  Wall time: 2min 30s
#     Test Scores: {'f1': 0.0063, 'pr': 0.8824, 'rc': 0.0031}
#
#   gbc:  Wall time: 12min 59s
#     Test Scores: {'f1': 0.0004, 'pr': 0.3333, 'rc': 0.0002}
#
#   xgb:  [16:23:25] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 41.3 s
#     Test Scores: {'f1': 0.1308, 'pr': 0.4057, 'rc': 0.078}
#
#   mlp:  Wall time: 4min 42s
#     Test Scores: {'f1': 0.2053, 'pr': 0.2783, 'rc': 0.1626}
#
# 20210806h:
#   gnb:  Wall time: 794 ms
#     Test Scores: {'f1': 0.3285, 'pr': 0.2351, 'rc': 0.545}
#
#   lrc:  Wall time: 1min 40s
#     Test Scores: {'f1': 0.002, 'pr': 0.4, 'rc': 0.001}
#
#   rfc:  Wall time: 12.6 s
#     Test Scores: {'f1': 0.0572, 'pr': 0.4106, 'rc': 0.0307}
#
#   abc:  Wall time: 2min 30s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#
#   gbc:  Wall time: 13min 2s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#
#   xgb:  [16:46:47] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 41.8 s
#     Test Scores: {'f1': 0.0398, 'pr': 0.3556, 'rc': 0.0211}
#
#   mlp:  Wall time: 4min 45s
#     Test Scores: {'f1': 0.1992, 'pr': 0.2436, 'rc': 0.1685}
#
# 20210806i:
#   gnb:  Wall time: 815 ms
#     Test Scores: {'f1': 0.4817, 'pr': 0.4254, 'rc': 0.555}
#
#   lrc:  Wall time: 1min 17s
#     Test Scores: {'f1': 0.0591, 'pr': 0.5299, 'rc': 0.0313}
#
#   rfc:  Wall time: 12.9 s
#     Test Scores: {'f1': 0.2984, 'pr': 0.4531, 'rc': 0.2224}
#
#   abc:  Wall time: 2min 30s
#     Test Scores: {'f1': 0.1135, 'pr': 0.5097, 'rc': 0.0639}
#
#   gbc:  Wall time: 13min 7s
#     Test Scores: {'f1': 0.0651, 'pr': 0.5201, 'rc': 0.0347}
#
#   xgb:  [17:09:56] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 43.1 s
#     Test Scores: {'f1': 0.2535, 'pr': 0.4515, 'rc': 0.1762}
#
#   mlp:  Wall time: 4min 37s
#     Test Scores: {'f1': 0.3768, 'pr': 0.4239, 'rc': 0.3391}
#
# 20210806j:
#   gnb:  Wall time: 775 ms
#     Test Scores: {'f1': 0.3818, 'pr': 0.2931, 'rc': 0.5474}
#
#   lrc:  Wall time: 4min 20s
#     Test Scores: {'f1': 0.0258, 'pr': 0.2153, 'rc': 0.0137}
#
#   rfc:  Wall time: 11.6 s
#     Test Scores: {'f1': 0.0402, 'pr': 0.2484, 'rc': 0.0218}
#
#   abc:  Wall time: 2min 28s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 12min 49s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#
#   xgb:  [17:35:38] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 39.7 s
#     Test Scores: {'f1': 0.0412, 'pr': 0.2576, 'rc': 0.0224}
#
#   mlp:  Wall time: 4min 34s
#     Test Scores: {'f1': 0.1971, 'pr': 0.2663, 'rc': 0.1565}
#
# 20210806k:
#   gnb:  Wall time: 800 ms
#     Test Scores: {'f1': 0.2653, 'pr': 0.1894, 'rc': 0.4424}
#
#   lrc:  Wall time: 4min 30s
#     Test Scores: {'f1': 0.0023, 'pr': 0.129, 'rc': 0.0011}
#
#   rfc:  Wall time: 12.8 s
#     Test Scores: {'f1': 0.0028, 'pr': 0.0794, 'rc': 0.0014}
#
#   abc:  Wall time: 2min 27s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#
#   gbc:  Wall time: 12min 40s
#     Test Scores: {'f1': 0.0011, 'pr': 0.25, 'rc': 0.0006}
#
#   xgb:  [18:01:14] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 39.7 s
#     Test Scores: {'f1': 0.0117, 'pr': 0.2121, 'rc': 0.006}
#
#   mlp:  Wall time: 4min 35s
#     Test Scores: {'f1': 0.1417, 'pr': 0.1858, 'rc': 0.1145}
#
# 20210806l:
#   gnb:  Wall time: 802 ms
#     Test Scores: {'f1': 0.3112, 'pr': 0.2573, 'rc': 0.3937}
#
#   lrc:  Wall time: 2min 46s
#     Test Scores: {'f1': 0.0022, 'pr': 0.2, 'rc': 0.0011}
#
#   rfc:  Wall time: 12.6 s
#     Test Scores: {'f1': 0.0065, 'pr': 0.1667, 'rc': 0.0033}
#
#   abc:  Wall time: 2min 26s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#
#   gbc:  Wall time: 12min 41s
#     Test Scores: {'f1': 0.0004, 'pr': 0.2, 'rc': 0.0002}
#
#   xgb:  [18:25:08] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 39.9 s
#     Test Scores: {'f1': 0.0126, 'pr': 0.2871, 'rc': 0.0064}
#
#   mlp:  Wall time: 4min 34s
#     Test Scores: {'f1': 0.1955, 'pr': 0.2404, 'rc': 0.1647}

# %% [markdown]
# # Limit to 3 lookbacks

# %%
import re

def get_columns(X_train,lookbacks):
    # Drop columns with lookbacks equal to or greater than X
    columns = list(X_train.columns)
    for c in X_train.columns:
        if m := re.match(r'^.*_([0-9]+)$', c):
            if int(m[1]) > lookbacks:
                columns.remove(c)
    return columns


def add_scores(dname, clf_name, train_scores, test_scores):
    try:
        data_file_df = pd.read_pickle(f'data/data_file_hist_some_cols.pkl')
        if dname in data_file_df.index:
            train_name = f'{clf_name}_train_scores'
            test_name = f'{clf_name}_test_scores'
            data_file_df.at[dname,train_name] = f'{train_scores}'
            data_file_df.at[dname,test_name] = f'{test_scores}'
            data_file_df.to_pickle(f'data/data_file_hist_some_cols.pkl')
    except Exception as e:
        #raise e
        print(f'Exception ({dname},{clf_name}): ', e)

clfs = {
    'gnb' : GaussianNB(),
    'lrc' : LogisticRegression(random_state=42, max_iter=10000),
    'rfc' : RandomForestClassifier(random_state=42, n_jobs=-1),
    'abc' : AdaBoostClassifier(random_state=42),
    'gbc': GradientBoostingClassifier(random_state=42),
    'xgb' : xgb.XGBClassifier(n_jobs=-1, random_state=42, use_label_encoder=False),
    'mlp' : make_pipeline(StandardScaler(),MLPClassifier(random_state=42)),
}

for dname, data in datasets.items():
    print(f'{dname}:')
    
    columns = get_columns(data['X_train'],lookbacks=3)
    data['X_train'] = data['X_train'][columns]
    data['X_test'] = data['X_test'][columns]
    
    for clf_name,clf in clfs.items():
        print(f'  {clf_name}:  ',end='')
        # %time clf.fit(data['X_train'], data['y_train'])
        train_scores = score_clf(clf, data['X_train'], data['y_train'])
        test_scores = score_clf(clf, data['X_test'], data['y_test'])
        add_scores(dname, clf_name, train_scores, test_scores)
        print('    Test Scores:', test_scores)
    print(' ')
# Out:
# 20210806a:
#   gnb:  Wall time: 219 ms
#     Test Scores: {'f1': 0.3709, 'pr': 0.3565, 'rc': 0.3866}
#   lrc:  Wall time: 33.6 s
#     Test Scores: {'f1': 0.0068, 'pr': 0.2973, 'rc': 0.0034}
#   rfc:  Wall time: 5.31 s
#     Test Scores: {'f1': 0.1973, 'pr': 0.3709, 'rc': 0.1344}
#   abc:  Wall time: 39.9 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 3min 24s
#     Test Scores: {'f1': 0.0003, 'pr': 0.5, 'rc': 0.0002}
#   xgb:  [18:47:44] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 11.1 s
#     Test Scores: {'f1': 0.1308, 'pr': 0.3145, 'rc': 0.0826}
#   mlp:  Wall time: 1min 47s
#     Test Scores: {'f1': 0.1447, 'pr': 0.3541, 'rc': 0.0909}
#
# 20210806b:
#   gnb:  Wall time: 213 ms
#     Test Scores: {'f1': 0.2737, 'pr': 0.2234, 'rc': 0.3534}
#   lrc:  Wall time: 43.9 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   rfc:  Wall time: 5.7 s
#     Test Scores: {'f1': 0.0243, 'pr': 0.2825, 'rc': 0.0127}
#   abc:  Wall time: 40 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 3min 24s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   xgb:  [18:54:47] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 11.2 s
#     Test Scores: {'f1': 0.0343, 'pr': 0.3532, 'rc': 0.018}
#   mlp:  Wall time: 1min 43s
#     Test Scores: {'f1': 0.0372, 'pr': 0.221, 'rc': 0.0203}
#
# 20210806c:
#   gnb:  Wall time: 219 ms
#     Test Scores: {'f1': 0.361, 'pr': 0.2692, 'rc': 0.5478}
#   lrc:  Wall time: 41.8 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   rfc:  Wall time: 6.66 s
#     Test Scores: {'f1': 0.024, 'pr': 0.3602, 'rc': 0.0124}
#   abc:  Wall time: 39.6 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 3min 24s
#     Test Scores: {'f1': 0.0013, 'pr': 0.1765, 'rc': 0.0006}
#   xgb:  [19:01:45] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 11.1 s
#     Test Scores: {'f1': 0.0211, 'pr': 0.3188, 'rc': 0.0109}
#   mlp:  Wall time: 1min 34s
#     Test Scores: {'f1': 0.123, 'pr': 0.2915, 'rc': 0.078}
#
# 20210806d:
#   gnb:  Wall time: 218 ms
#     Test Scores: {'f1': 0.4233, 'pr': 0.3739, 'rc': 0.4879}
#   lrc:  Wall time: 29.3 s
#     Test Scores: {'f1': 0.0044, 'pr': 0.4412, 'rc': 0.0022}
#   rfc:  Wall time: 5.87 s
#     Test Scores: {'f1': 0.1763, 'pr': 0.3971, 'rc': 0.1133}
#   abc:  Wall time: 39.6 s
#     Test Scores: {'f1': 0.0009, 'pr': 0.4286, 'rc': 0.0004}
#   gbc:  Wall time: 3min 24s
#     Test Scores: {'f1': 0.0009, 'pr': 0.5, 'rc': 0.0004}
#   xgb:  [19:08:20] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 11.2 s
#     Test Scores: {'f1': 0.1624, 'pr': 0.3909, 'rc': 0.1025}
#   mlp:  Wall time: 1min 46s
#     Test Scores: {'f1': 0.1965, 'pr': 0.3634, 'rc': 0.1346}
#
# 20210806e:
#   gnb:  Wall time: 220 ms
#     Test Scores: {'f1': 0.2225, 'pr': 0.1593, 'rc': 0.369}
#   lrc:  Wall time: 15.4 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   rfc:  Wall time: 6.08 s
#     Test Scores: {'f1': 0.0071, 'pr': 0.2647, 'rc': 0.0036}
#   abc:  Wall time: 39.6 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 3min 24s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   xgb:  [19:14:54] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 11.1 s
#     Test Scores: {'f1': 0.0391, 'pr': 0.3023, 'rc': 0.0209}
#   mlp:  Wall time: 1min 27s
#     Test Scores: {'f1': 0.0458, 'pr': 0.1852, 'rc': 0.0261}
#
# 20210806f:
#   gnb:  Wall time: 216 ms
#     Test Scores: {'f1': 0.2101, 'pr': 0.1473, 'rc': 0.3663}
#   lrc:  Wall time: 23.7 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   rfc:  Wall time: 6.21 s
#     Test Scores: {'f1': 0.0036, 'pr': 0.1739, 'rc': 0.0018}
#   abc:  Wall time: 39.7 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 3min 24s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   xgb:  [19:21:17] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 11 s
#     Test Scores: {'f1': 0.0174, 'pr': 0.2703, 'rc': 0.009}
#   mlp:  Wall time: 1min 47s
#     Test Scores: {'f1': 0.0535, 'pr': 0.1786, 'rc': 0.0315}
#
# 20210806g:
#   gnb:  Wall time: 216 ms
#     Test Scores: {'f1': 0.3713, 'pr': 0.283, 'rc': 0.5396}
#   lrc:  Wall time: 16.5 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   rfc:  Wall time: 5.49 s
#     Test Scores: {'f1': 0.1706, 'pr': 0.4751, 'rc': 0.1039}
#   abc:  Wall time: 39.9 s
#     Test Scores: {'f1': 0.0004, 'pr': 1.0, 'rc': 0.0002}
#   gbc:  Wall time: 3min 24s
#     Test Scores: {'f1': 0.0004, 'pr': 0.2, 'rc': 0.0002}
#   xgb:  [19:27:52] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 11.3 s
#     Test Scores: {'f1': 0.157, 'pr': 0.3741, 'rc': 0.0993}
#   mlp:  Wall time: 1min 37s
#     Test Scores: {'f1': 0.0885, 'pr': 0.3297, 'rc': 0.0511}
#
# 20210806h:
#   gnb:  Wall time: 201 ms
#     Test Scores: {'f1': 0.3245, 'pr': 0.2409, 'rc': 0.4969}
#   lrc:  Wall time: 20.9 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   rfc:  Wall time: 5.86 s
#     Test Scores: {'f1': 0.1007, 'pr': 0.4481, 'rc': 0.0568}
#   abc:  Wall time: 40.4 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 3min 25s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   xgb:  [19:34:24] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 11.1 s
#     Test Scores: {'f1': 0.0948, 'pr': 0.3756, 'rc': 0.0543}
#   mlp:  Wall time: 1min 49s
#     Test Scores: {'f1': 0.0953, 'pr': 0.2848, 'rc': 0.0572}
#
# 20210806i:
#   gnb:  Wall time: 205 ms
#     Test Scores: {'f1': 0.486, 'pr': 0.4305, 'rc': 0.5581}
#   lrc:  Wall time: 9.79 s
#     Test Scores: {'f1': 0.0297, 'pr': 0.5708, 'rc': 0.0152}
#   rfc:  Wall time: 6.09 s
#     Test Scores: {'f1': 0.3219, 'pr': 0.4481, 'rc': 0.2512}
#   abc:  Wall time: 39.7 s
#     Test Scores: {'f1': 0.1097, 'pr': 0.4722, 'rc': 0.062}
#   gbc:  Wall time: 3min 25s
#     Test Scores: {'f1': 0.0896, 'pr': 0.5241, 'rc': 0.049}
#   xgb:  [19:40:56] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 11.1 s
#     Test Scores: {'f1': 0.3195, 'pr': 0.4459, 'rc': 0.2489}
#   mlp:  Wall time: 1min 46s
#     Test Scores: {'f1': 0.2728, 'pr': 0.4186, 'rc': 0.2023}
#
# 20210806j:
#   gnb:  Wall time: 203 ms
#     Test Scores: {'f1': 0.3402, 'pr': 0.2908, 'rc': 0.4097}
#   lrc:  Wall time: 57.4 s
#     Test Scores: {'f1': 0.007, 'pr': 0.125, 'rc': 0.0036}
#   rfc:  Wall time: 5.46 s
#     Test Scores: {'f1': 0.0637, 'pr': 0.2591, 'rc': 0.0363}
#   abc:  Wall time: 39.8 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 3min 24s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   xgb:  [19:48:10] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 11 s
#     Test Scores: {'f1': 0.0561, 'pr': 0.3071, 'rc': 0.0309}
#   mlp:  Wall time: 1min 46s
#     Test Scores: {'f1': 0.1041, 'pr': 0.2862, 'rc': 0.0636}
#
# 20210806k:
#   gnb:  Wall time: 243 ms
#     Test Scores: {'f1': 0.1594, 'pr': 0.2136, 'rc': 0.1271}
#   lrc:  Wall time: 46.8 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   rfc:  Wall time: 5.79 s
#     Test Scores: {'f1': 0.0131, 'pr': 0.1481, 'rc': 0.0069}
#   abc:  Wall time: 39.6 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 3min 24s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   xgb:  [19:55:15] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 11 s
#     Test Scores: {'f1': 0.0187, 'pr': 0.2394, 'rc': 0.0097}
#   mlp:  Wall time: 1min 49s
#     Test Scores: {'f1': 0.0551, 'pr': 0.1871, 'rc': 0.0323}
#
# 20210806l:
#   gnb:  Wall time: 204 ms
#     Test Scores: {'f1': 0.2909, 'pr': 0.2572, 'rc': 0.3348}
#   lrc:  Wall time: 41.1 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   rfc:  Wall time: 5.85 s
#     Test Scores: {'f1': 0.0187, 'pr': 0.2115, 'rc': 0.0098}
#   abc:  Wall time: 39.8 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 3min 24s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   xgb:  [20:02:17] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 11.1 s
#     Test Scores: {'f1': 0.01, 'pr': 0.284, 'rc': 0.0051}
#   mlp:  Wall time: 1min 31s
#     Test Scores: {'f1': 0.0919, 'pr': 0.2816, 'rc': 0.0549}

# %% [markdown]
# # No lookbacks

# %%
def add_scores(dname, clf_name, train_scores, test_scores):
    try:
        data_file_df = pd.read_pickle(f'data/data_file_hist_no_lkbk.pkl')
        if dname in data_file_df.index:
            train_name = f'{clf_name}_train_scores'
            test_name = f'{clf_name}_test_scores'
            data_file_df.at[dname,train_name] = f'{train_scores}'
            data_file_df.at[dname,test_name] = f'{test_scores}'
            data_file_df.to_pickle(f'data/data_file_hist_no_lkbk.pkl')
    except Exception as e:
        #raise e
        print(f'Exception ({dname},{clf_name}): ', e)

clfs = {
    'gnb' : GaussianNB(),
    'lrc' : LogisticRegression(random_state=42, max_iter=10000),
    'rfc' : RandomForestClassifier(random_state=42, n_jobs=-1),
    'abc' : AdaBoostClassifier(random_state=42),
    'gbc': GradientBoostingClassifier(random_state=42),
    'xgb' : xgb.XGBClassifier(n_jobs=-1, random_state=42, use_label_encoder=False),
    'mlp' : make_pipeline(StandardScaler(),MLPClassifier(random_state=42)),
}

for dname, data in datasets.items():
    print(f'{dname}:')
    
    columns = get_columns(data['X_train'],lookbacks=0)
    data['X_train'] = data['X_train'][columns]
    data['X_test'] = data['X_test'][columns]
    
    for clf_name,clf in clfs.items():
        print(f'  {clf_name}:  ',end='')
        # %time clf.fit(data['X_train'], data['y_train'])
        train_scores = score_clf(clf, data['X_train'], data['y_train'])
        test_scores = score_clf(clf, data['X_test'], data['y_test'])
        add_scores(dname, clf_name, train_scores, test_scores)
        print('    Test Scores:', test_scores)
    print(' ')
# Out:
# 20210806a:
#   gnb:  Wall time: 58.9 ms
#     Test Scores: {'f1': 0.0217, 'pr': 0.3077, 'rc': 0.0113}
#   lrc:  Wall time: 655 ms
#     Test Scores: {'f1': 0.0016, 'pr': 0.2083, 'rc': 0.0008}
#   rfc:  Wall time: 2.46 s
#     Test Scores: {'f1': 0.211, 'pr': 0.3804, 'rc': 0.146}
#   abc:  Wall time: 10.8 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 52.8 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   xgb:  [20:23:30] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 4.01 s
#     Test Scores: {'f1': 0.1685, 'pr': 0.3605, 'rc': 0.11}
#   mlp:  Wall time: 39 s
#     Test Scores: {'f1': 0.1116, 'pr': 0.4145, 'rc': 0.0645}
#
# 20210806b:
#   gnb:  Wall time: 56.8 ms
#     Test Scores: {'f1': 0.0148, 'pr': 0.2586, 'rc': 0.0076}
#   lrc:  Wall time: 655 ms
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   rfc:  Wall time: 2.67 s
#     Test Scores: {'f1': 0.038, 'pr': 0.3008, 'rc': 0.0203}
#   abc:  Wall time: 10.7 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 53 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   xgb:  [20:25:24] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 4.01 s
#     Test Scores: {'f1': 0.0153, 'pr': 0.265, 'rc': 0.0079}
#   mlp:  Wall time: 47.9 s
#     Test Scores: {'f1': 0.0255, 'pr': 0.4031, 'rc': 0.0132}
#
# 20210806c:
#   gnb:  Wall time: 64.8 ms
#     Test Scores: {'f1': 0.182, 'pr': 0.2573, 'rc': 0.1408}
#   lrc:  Wall time: 664 ms
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   rfc:  Wall time: 2.9 s
#     Test Scores: {'f1': 0.042, 'pr': 0.3302, 'rc': 0.0224}
#   abc:  Wall time: 10.6 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 53.4 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   xgb:  [20:27:28] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 3.92 s
#     Test Scores: {'f1': 0.0222, 'pr': 0.2857, 'rc': 0.0115}
#   mlp:  Wall time: 53.8 s
#     Test Scores: {'f1': 0.0117, 'pr': 0.28, 'rc': 0.006}
#
# 20210806d:
#   gnb:  Wall time: 57.8 ms
#     Test Scores: {'f1': 0.0753, 'pr': 0.3689, 'rc': 0.0419}
#   lrc:  Wall time: 776 ms
#     Test Scores: {'f1': 0.0017, 'pr': 0.6, 'rc': 0.0009}
#   rfc:  Wall time: 2.94 s
#     Test Scores: {'f1': 0.1975, 'pr': 0.3904, 'rc': 0.1322}
#   abc:  Wall time: 10.6 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 53.5 s
#     Test Scores: {'f1': 0.0026, 'pr': 0.6, 'rc': 0.0013}
#   xgb:  [20:29:38] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 4.06 s
#     Test Scores: {'f1': 0.1707, 'pr': 0.3983, 'rc': 0.1086}
#   mlp:  Wall time: 60 s
#     Test Scores: {'f1': 0.1145, 'pr': 0.4266, 'rc': 0.0662}
#
# 20210806e:
#   gnb:  Wall time: 59.8 ms
#     Test Scores: {'f1': 0.0102, 'pr': 0.1857, 'rc': 0.0052}
#   lrc:  Wall time: 851 ms
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   rfc:  Wall time: 3.05 s
#     Test Scores: {'f1': 0.0125, 'pr': 0.2222, 'rc': 0.0064}
#   abc:  Wall time: 10.8 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 53.4 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   xgb:  [20:31:55] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 3.91 s
#     Test Scores: {'f1': 0.0627, 'pr': 0.4421, 'rc': 0.0338}
#   mlp:  Wall time: 58.5 s
#     Test Scores: {'f1': 0.0179, 'pr': 0.2805, 'rc': 0.0092}
#
# 20210806f:
#   gnb:  Wall time: 60.8 ms
#     Test Scores: {'f1': 0.0314, 'pr': 0.1054, 'rc': 0.0184}
#   lrc:  Wall time: 764 ms
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   rfc:  Wall time: 3.14 s
#     Test Scores: {'f1': 0.0071, 'pr': 0.2667, 'rc': 0.0036}
#   abc:  Wall time: 10.8 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 52.6 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   xgb:  [20:34:09] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 3.93 s
#     Test Scores: {'f1': 0.0731, 'pr': 0.3434, 'rc': 0.0409}
#   mlp:  Wall time: 58.5 s
#     Test Scores: {'f1': 0.007, 'pr': 0.1633, 'rc': 0.0036}
#
# 20210806g:
#   gnb:  Wall time: 57.8 ms
#     Test Scores: {'f1': 0.0609, 'pr': 0.3306, 'rc': 0.0335}
#   lrc:  Wall time: 663 ms
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   rfc:  Wall time: 2.61 s
#     Test Scores: {'f1': 0.1669, 'pr': 0.4138, 'rc': 0.1046}
#   abc:  Wall time: 10.5 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 52.3 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   xgb:  [20:36:22] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 3.92 s
#     Test Scores: {'f1': 0.1447, 'pr': 0.4017, 'rc': 0.0882}
#   mlp:  Wall time: 1min
#     Test Scores: {'f1': 0.0823, 'pr': 0.3982, 'rc': 0.0459}
#
# 20210806h:
#   gnb:  Wall time: 58.8 ms
#     Test Scores: {'f1': 0.0455, 'pr': 0.2282, 'rc': 0.0253}
#   lrc:  Wall time: 582 ms
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   rfc:  Wall time: 2.7 s
#     Test Scores: {'f1': 0.1002, 'pr': 0.401, 'rc': 0.0572}
#   abc:  Wall time: 10.6 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 52.5 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   xgb:  [20:38:37] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 3.88 s
#     Test Scores: {'f1': 0.0986, 'pr': 0.3367, 'rc': 0.0577}
#   mlp:  Wall time: 58.8 s
#     Test Scores: {'f1': 0.0588, 'pr': 0.3686, 'rc': 0.032}
#
# 20210806i:
#   gnb:  Wall time: 55.9 ms
#     Test Scores: {'f1': 0.2811, 'pr': 0.4655, 'rc': 0.2013}
#   lrc:  Wall time: 781 ms
#     Test Scores: {'f1': 0.0161, 'pr': 0.6204, 'rc': 0.0082}
#   rfc:  Wall time: 3 s
#     Test Scores: {'f1': 0.33, 'pr': 0.4342, 'rc': 0.2662}
#   abc:  Wall time: 10.6 s
#     Test Scores: {'f1': 0.1327, 'pr': 0.4781, 'rc': 0.077}
#   gbc:  Wall time: 52.5 s
#     Test Scores: {'f1': 0.1138, 'pr': 0.4925, 'rc': 0.0644}
#   xgb:  [20:40:52] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 3.96 s
#     Test Scores: {'f1': 0.2855, 'pr': 0.4452, 'rc': 0.2101}
#   mlp:  Wall time: 1min 5s
#     Test Scores: {'f1': 0.2606, 'pr': 0.4477, 'rc': 0.1838}
#
# 20210806j:
#   gnb:  Wall time: 53.9 ms
#     Test Scores: {'f1': 0.1299, 'pr': 0.2583, 'rc': 0.0868}
#   lrc:  Wall time: 2.4 s
#     Test Scores: {'f1': 0.0037, 'pr': 0.0885, 'rc': 0.0019}
#   rfc:  Wall time: 2.55 s
#     Test Scores: {'f1': 0.0935, 'pr': 0.2588, 'rc': 0.0571}
#   abc:  Wall time: 10.6 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 52.5 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   xgb:  [20:43:14] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 3.95 s
#     Test Scores: {'f1': 0.0632, 'pr': 0.252, 'rc': 0.0362}
#   mlp:  Wall time: 1min 4s
#     Test Scores: {'f1': 0.0425, 'pr': 0.354, 'rc': 0.0226}
#
# 20210806k:
#   gnb:  Wall time: 53.9 ms
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   lrc:  Wall time: 2.17 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   rfc:  Wall time: 2.66 s
#     Test Scores: {'f1': 0.0302, 'pr': 0.2127, 'rc': 0.0163}
#   abc:  Wall time: 10.6 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 52.4 s
#     Test Scores: {'f1': 0.0006, 'pr': 1.0, 'rc': 0.0003}
#   xgb:  [20:45:34] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 3.89 s
#     Test Scores: {'f1': 0.0236, 'pr': 0.1442, 'rc': 0.0129}
#   mlp:  Wall time: 38.5 s
#     Test Scores: {'f1': 0.0011, 'pr': 0.1818, 'rc': 0.0006}
#
# 20210806l:
#   gnb:  Wall time: 54.9 ms
#     Test Scores: {'f1': 0.0152, 'pr': 0.2917, 'rc': 0.0078}
#   lrc:  Wall time: 1.74 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   rfc:  Wall time: 2.76 s
#     Test Scores: {'f1': 0.0485, 'pr': 0.2874, 'rc': 0.0265}
#   abc:  Wall time: 10.5 s
#     Test Scores: {'f1': 0.0, 'pr': 0.0, 'rc': 0.0}
#   gbc:  Wall time: 52.3 s
#     Test Scores: {'f1': 0.0004, 'pr': 0.3333, 'rc': 0.0002}
#   xgb:  [20:47:28] WARNING: ..\src\learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 3.88 s
#     Test Scores: {'f1': 0.0185, 'pr': 0.2945, 'rc': 0.0096}
#   mlp:  Wall time: 51.7 s
#     Test Scores: {'f1': 0.0088, 'pr': 0.2778, 'rc': 0.0044}
